# %%
from modelseedpy.biochem import from_local

# msdb = from_local("/Users/afreiburger/Documents/ModelSEEDDatabase")
msdb = from_local(r"C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase")
# Out:
# modelseedpy 0.2.2

# %%
from json import load, dump
from glob import glob

MSDB_json = {}
for jsonData in glob(r"C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_*.json"):
    print(jsonData)
    with open(jsonData, "r") as jsonIn:
        iteration = load(jsonIn)
        iteration_dic = {}
        for rxnInfo in iteration:
            iteration_dic.update({rxnInfo["id"]: rxnInfo})
        MSDB_json.update(iteration_dic)
# Out:
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_00.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_01.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_02.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_03.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_04.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_05.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_06.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_07.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_08.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_09.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_10.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_11.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_12.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_13.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_14.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_15.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_16.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_17.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_18.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_19.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_20.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_21.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_22.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_23.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_24.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_25.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_26.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_27.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_28.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_29.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_30.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_31.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_32.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_33.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_34.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_35.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_36.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_37.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_38.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_39.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_40.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_41.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_42.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_43.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_44.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_45.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_46.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_47.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_48.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_49.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_50.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_51.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_52.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_53.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_54.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_55.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_56.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_57.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_58.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_59.json
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\reaction_60.json

# %%
# sorted(list(MSDB_json.keys()))
print(len(MSDB_json.keys()))
# Out:
# 56009

# %%
from numpy import nan
import re

thermo_values = {}
for file in glob(r"C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase\Biochemistry\Thermodynamics\dGPredictor\json_files\*.json"):
    with open(file, "r") as jsonIn:
        iteration = load(jsonIn)
        rxnJson = {}
        # display(iteration)
        for k,v in iteration.items():
            if isinstance(v, str):  print(f"no dG for {k}") ; continue
            sub_dic_abbrev = MSDB_json[k]["abbreviation"]
            if MSDB_json[k]["abbreviation"] not in v:
                print(k, MSDB_json[k]["abbreviation"], v)
                rxnNum = int(k[3:])
                increase = 1
                sub_dic_abbrev = f"R{rxnNum+increase:05}"
                while sub_dic_abbrev not in v:
                    increase += 1
                    sub_dic_abbrev = f"R{increase:05}"
                    if increase >= 1e6:  print(f"The {k} reaction has not been processed") ; sub_dic_abbrev = None ; break
            if not sub_dic_abbrev:  continue
            if isinstance(v[sub_dic_abbrev], str):  print(f"no dG for {k}") ; continue
            parsed_num = re.sub("([0-9\.\-])", "", str(v[sub_dic_abbrev]["dG_mean"]))
            if parsed_num != "":  print(parsed_num, f"no dG for {k}", v) ; continue
            rxnJson.update({k: v[sub_dic_abbrev]})    
        thermo_values.update(rxnJson)
# Out:
# no dG for rxn00013
# no dG for rxn00014
# rxn00019 2NPDO {'R00024': {'dG_mean': -36.09110678486431, 'dG_uncer': 0.1531422933954736}}
# no dG for rxn00023
# no dG for rxn00027
# rxn00032 Choline:oxygen 1-oxidoreductase {'R00039': {'dG_mean': 9.89603019707367, 'dG_uncer': 1.2531104413742675}}
# rxn00037 R_R00047_c {'R00045': {'dG_mean': -620.0310043183184, 'dG_uncer': 5.776648052959535}}
# no dG for rxn00047
# rxn00050 rxn00050 {'R00066': {'dG_mean': 58.839374670830736, 'dG_uncer': 6.516833818782413}}
# rxn00053 Prostaglandin H2:oxygen oxidoreductase {'R00072': {'dG_mean': -145.56933011998268, 'dG_uncer': 0.7049128338919903}}
# nan no dG for rxn00056 {'R00078': {'dG_mean': nan, 'dG_uncer': nan}}
# no dG for rxn00058
# no dG for rxn00059
# nan no dG for rxn00068 {'R00092': {'dG_mean': nan, 'dG_uncer': nan}}
# rxn00073 rxn00073 {'R00097': {'dG_mean': 382.20282752091407, 'dG_uncer': 0.1109804195398385}}
# rxn00075 NADNm {'R00102': {'dG_mean': -18.099300482432312, 'dG_uncer': 1.031583345874511}}
# nan no dG for rxn00079 {'R00106': {'dG_mean': nan, 'dG_uncer': nan}}
# rxn00081 rxn00081 {'R00107': {'dG_mean': -379.7622044290665, 'dG_uncer': 0.1109804195398385}}
# rxn00082 (nitric-oxide-forming) {'R00107': {'dG_mean': -379.7622044290665, 'dG_uncer': 0.1109804195398385}}
# rxn00087 NADPH:CoA-glutathione oxidoreductase {'R00115': {'dG_mean': 17.185488557775273, 'dG_uncer': 0.1051766047969921}}
# rxn00091 rxn00091 {'R00120': {'dG_mean': -115.12693570903896, 'dG_uncer': 0.178940655831939}}
# rxn00104 PPK2r {'R00134': {'dG_mean': -14.494378206452616, 'dG_uncer': 0.1519716249425109}}
# rxn00110 deaminating) {'R00143': {'dG_mean': 255.0992477985833, 'dG_uncer': 1.9783399707494915}}
# rxn00111 deaminating) {'R00143': {'dG_mean': 255.0992477985833, 'dG_uncer': 1.9783399707494915}}
# rxn00112 rxn00112 {'R00143': {'dG_mean': 255.0992477985833, 'dG_uncer': 1.9783399707494915}}
# rxn00135 (S)-Lactate adenylohydrolase {'R00185': {'dG_mean': -14.342206162154524, 'dG_uncer': 0.102352361368536}}
# no dG for rxn00145
# no dG for rxn00146
# rxn00180 PRO1 {'R00239': {'dG_mean': 12.82527254400472, 'dG_uncer': 0.8943137209698793}}
# no dG for rxn00238
# no dG for rxn00240
# rxn00261 rxn00261 {'R00355': {'dG_mean': 3.013234063682944, 'dG_uncer': 0.1033233643730427}}
# no dG for rxn00267
# rxn00273 rbs_30 {'R00369': {'dG_mean': -11.256459730834608, 'dG_uncer': 0.1145939628006248}}
# rxn00277 rxn00277 {'R00373': {'dG_mean': 8.914943553231353, 'dG_uncer': 0.1141681552861562}}
# rxn00281 rxn00281 {'R00398': {'dG_mean': 34.98656000030442, 'dG_uncer': 0.1436801134192741}}
# no dG for rxn00296
# rxn00319 rxn00319 {'R10277': {'dG_mean': -24.945900216016756, 'dG_uncer': 0.1754008364808223}}
# rxn00349 rxn00349 {'R00491': {'dG_mean': 6.726202817075119, 'dG_uncer': 0.6707008618747331}}
# rxn00353 rxn00353 {'R00499': {'dG_mean': -28.54934528099696, 'dG_uncer': 1.5022251157609732}}
# no dG for rxn00378
# no dG for rxn00388
# no dG for rxn00389
# no dG for rxn00390
# rxn00397 NAD+:L-arginine ADP-D-ribosyltransferase {'R00554': {'dG_mean': 5.32685804928218, 'dG_uncer': 0.1030939940533578}}
# rxn00398 ARG-OXIDATION-RXN.c {'R00554': {'dG_mean': 5.32685804928218, 'dG_uncer': 0.1030939940533578}}
# rxn00399 L-Arginine,NADPH:oxygen oxidoreductase (nitric-oxide-forming) {'R00554': {'dG_mean': 5.32685804928218, 'dG_uncer': 0.1030939940533578}}
# rxn00418 ENTF-RXN.c {'R00579': {'dG_mean': 0.1792497300114952, 'dG_uncer': 0.1258386443866851}}
# rxn00431 Methylamine:(acceptor) oxidoreductase (deaminating) {'R00605': {'dG_mean': 35.48459752417806, 'dG_uncer': 0.1525904918525396}}
# rxn00442 2-OXOGLUT-DECARBOX-RXN.c {'R00621': {'dG_mean': -46.74201706894695, 'dG_uncer': 1.8082774709659408}}
# no dG for rxn00443
# rxn00447 R_R00645_c {'R00643': {'dG_mean': -103.1544704752639, 'dG_uncer': 2.2471189246502425}}
# rxn00496 R_R00698_c {'R00697': {'dG_mean': -3.3371458453034397, 'dG_uncer': 0.1034090978029984}}
# rxn00535 rxn00535 {'R00743': {'dG_mean': -4.037758006532812, 'dG_uncer': 0.5728705418096631}}
# no dG for rxn00567
# rxn00568 NIRBD-RXN.c {'R00787': {'dG_mean': 402.1655031883122, 'dG_uncer': 0.1613884466895409}}
# rxn00569 RXN0-6377.c.metaexp.NADP_NADPH {'R00789': {'dG_mean': 394.8436339127691, 'dG_uncer': 0.1613884466895409}}
# rxn00574 rxn00574 {'R00799': {'dG_mean': 118.01669878252622, 'dG_uncer': 1.9511170626845349}}
# rxn00590 decarboxylating) {'R00818': {'dG_mean': -348.51332218993207, 'dG_uncer': 1.5276445676820938}}
# rxn00591 (decarboxylating) {'R00818': {'dG_mean': -348.51332218993207, 'dG_uncer': 1.5276445676820938}}
# rxn00597 2-NITROPHENOL-2-MONOOXYGENASE-RXN.c {'R00827': {'dG_mean': -96.72332265783588, 'dG_uncer': 3.3347351268533547}, 'R07330': {'dG_mean': -96.72332265783588, 'dG_uncer': 3.3347351268533547}}
# rxn00600 Succinyl-CoA:glycine C-succinyl-transferase(decarboxylating) {'R00830': {'dG_mean': -9.804267681432831, 'dG_uncer': 0.8453146984725246}}
# rxn00609 MI1PS {'R00839': {'dG_mean': -6.003515971478265, 'dG_uncer': 0.9377192322432408}}
# no dG for rxn00622
# no dG for rxn00626
# rxn00663 rxn00663 {'R00913': {'dG_mean': -26.7428150710833, 'dG_uncer': 1.219674931266031}}
# no dG for rxn00664
# no dG for rxn00665
# no dG for rxn00666
# no dG for rxn00667
# rxn00681 rxn00681 {'R00932': {'dG_mean': 43.62234605293585, 'dG_uncer': 0.9258872747478568}}
# rxn00685 R_R00937_c {'R00936': {'dG_mean': 29.763269277091663, 'dG_uncer': 0.1086244130230917}}
# rxn00687 R_R00940_c {'R00939': {'dG_mean': 27.32264618524377, 'dG_uncer': 0.1086244130230917}}
# no dG for rxn00732
# no dG for rxn00733
# no dG for rxn00734
# rxn00750 rxn00750 {'R01019': {'dG_mean': 81.76856746549186, 'dG_uncer': 4.093496019300068}}
# nan no dG for rxn00755 {'R01027': {'dG_mean': nan, 'dG_uncer': nan}}
# nan no dG for rxn00756 {'R01028': {'dG_mean': nan, 'dG_uncer': nan}}
# no dG for rxn00757
# rxn00759 3-Chloro-D-alanine chloride-lyase (deaminating) {'R01030': {'dG_mean': -27.35485064678465, 'dG_uncer': 1.340097098703758}}
# rxn00760 rxn00760 {'R01030': {'dG_mean': -27.35485064678465, 'dG_uncer': 1.340097098703758}}
# rxn00761 dechlorinating, decarboxylating) {'R01030': {'dG_mean': -27.35485064678465, 'dG_uncer': 1.340097098703758}}
# rxn00796 BTS3r {'R01077': {'dG_mean': 6.7593243853112455, 'dG_uncer': 2.640712309250748}}
# rxn00809 D-Galactose:NAD+ 1-oxidoreductase {'R01092': {'dG_mean': -24.007846055222387, 'dG_uncer': 1.3620128168363297}}
# rxn00811 D-Galactose:NADP+ 1-oxidoreductase {'R01094': {'dG_mean': -14.546107502701318, 'dG_uncer': 0.1117094702593299}}
# rxn00820 Nitrite:(acceptor) oxidoreductase {'R01104': {'dG_mean': 4.374925088201337, 'dG_uncer': 1.5657484228364358}}
# no dG for rxn00828
# rxn00847 rxn00847 {'R01145': {'dG_mean': -41.66873477481092, 'dG_uncer': 2.212889847692709}}
# rxn00887 myo-Inositol 6-O-methyltransferase {'R01190': {'dG_mean': -38.77295743592512, 'dG_uncer': 3.5660033905328827}}
# rxn00909 R_R01222_c {'R01221': {'dG_mean': 24.45253488307918, 'dG_uncer': 0.160611018201239}}
# rxn00955 RHCYS {'R01289': {'dG_mean': -20.93020947979768, 'dG_uncer': 2.4845110607752634}}
# rxn00969 4-Chlorobenzoate chlorohydrolase {'R01305': {'dG_mean': -514.796897665907, 'dG_uncer': 1.5122368416305876}}
# no dG for rxn00982
# no dG for rxn00983
# no dG for rxn00984
# no dG for rxn01006
# no dG for rxn01040
# no dG for rxn01047
# rxn01055 D-LACTATE-2-SULFATASE-RXN.c {'R01447': {'dG_mean': -3.094707788107769, 'dG_uncer': 0.1033339507838793}}
# rxn01059 rxn01059 {'R01451': {'dG_mean': 43.32642689092762, 'dG_uncer': 4.247948561138009}}
# rxn01061 Cholesterol:oxygen oxidoreductase (side-chain-cleaving) {'R01453': {'dG_mean': -325.3226740035659, 'dG_uncer': 2.803329779457304}}
# no dG for rxn01066
# rxn01077 ATP:D-glucuronate 1-phosphotransferase {'R01476': {'dG_mean': -10.485741787904004, 'dG_uncer': 0.7454598337358287}}
# no dG for rxn01078
# rxn01084 ATP:cob(I)alamin Co-beta-adenosyltransferase {'R01492': {'dG_mean': -523.608578504341, 'dG_uncer': 0.111950103855723}}
# no dG for rxn01085
# no dG for rxn01087
# no dG for rxn01088
# no dG for rxn01089
# no dG for rxn01090
# no dG for rxn01091
# no dG for rxn01092
# rxn01097 2,3-Dihydroxybenzoate:L-serine ligase {'R01507': {'dG_mean': -474.7065644518504, 'dG_uncer': 2.2167270946372235}}
# rxn01098 2,3-Dihydroxybenzoate:L-serine ligase {'R01507': {'dG_mean': -474.7065644518504, 'dG_uncer': 2.2167270946372235}}
# no dG for rxn01120
# no dG for rxn01155
# rxn01178 reac_522 {'R01611': {'dG_mean': -82.2716205126289, 'dG_uncer': 2.7410603761383587}}
# no dG for rxn01198
# rxn01209 FTHFI {'R01652': {'dG_mean': 18.79044736837443, 'dG_uncer': 1.157179892255332}}
# rxn01213 reac_398 {'R01658': {'dG_mean': -88.86204329963161, 'dG_uncer': 3.723020445901893}}
# rxn01228 R_R01679_c {'R01677': {'dG_mean': -7.645168897315571, 'dG_uncer': 0.1199188738151499}}
# rxn01229 Lactose:(acceptor) 3-oxidoreductase {'R01677': {'dG_mean': -7.645168897315571, 'dG_uncer': 0.1199188738151499}}
# no dG for rxn01234
# no dG for rxn01235
# no dG for rxn01242
# no dG for rxn01243
# no dG for rxn01244
# no dG for rxn01245
# rxn01250 Pyridoxal:oxygen 4-oxidoreductase {'R01708': {'dG_mean': 28.35155633320801, 'dG_uncer': 0.12442684165671}}
# rxn01259 MLTG7 {'R01717': {'dG_mean': 0.9893187289453992, 'dG_uncer': 0.1173216845872269}}
# rxn01264 rxn01264 {'R01722': {'dG_mean': -25.517009936187065, 'dG_uncer': 0.8364970025992486}}
# no dG for rxn01266
# no dG for rxn01267
# no dG for rxn01272
# rxn01288 D-threo-Aldose:NAD+ 1-oxidoreductase {'R01754': {'dG_mean': -13.756728582773036, 'dG_uncer': 1.5767123594438863}}
# nan no dG for rxn01321 {'R01810': {'dG_mean': nan, 'dG_uncer': nan}}
# no dG for rxn01339
# no dG for rxn01340
# rxn01342 rxn01342 {'R01841': {'dG_mean': 14.158700567627974, 'dG_uncer': 3.053349211937433}}
# rxn01346 CTP:Sedoheptulose 7-phosphate 1-phosphotransferase {'R01845': {'dG_mean': -15.237395384338242, 'dG_uncer': 0.1101741025426248}}
# rxn01347 UTP:Sedoheptulose 7-phosphate 1-phosphotransferase {'R01845': {'dG_mean': -15.237395384338242, 'dG_uncer': 0.1101741025426248}}
# rxn01348 ITP:Sedoheptulose 7-phosphate 1-phosphotransferase {'R01845': {'dG_mean': -15.237395384338242, 'dG_uncer': 0.1101741025426248}}
# no dG for rxn01381
# no dG for rxn01382
# no dG for rxn01400
# rxn01402 N1-Acetylspermidine amidohydrolase {'R01914': {'dG_mean': -62.151787879785104, 'dG_uncer': 2.0677804341571875}}
# rxn01412 rxn01412 {'R01926': {'dG_mean': -14.257413670128017, 'dG_uncer': 0.1024899850834725}}
# rxn01424 OXOADLR {'R01939': {'dG_mean': 0.4788852089121249, 'dG_uncer': 0.1241027921637313}}
# no dG for rxn01432
# no dG for rxn01433
# rxn01470 rxn01470 {'R02007': {'dG_mean': 15.243756828670303, 'dG_uncer': 4.125127542109102}}
# rxn01481 (R)-3-Amino-2-methylpropanoate:2-oxoglutarate aminotransferase {'R02047': {'dG_mean': 21.365895815176373, 'dG_uncer': 0.1173188246007091}}
# rxn01491 D-Fructose 1,6-bisphosphate phosphohydrolase {'R02068': {'dG_mean': -20.815373001983623, 'dG_uncer': 6.575875508927252}}
# no dG for rxn01497
# no dG for rxn01498
# no dG for rxn01526
# no dG for rxn01533
# no dG for rxn01534
# rxn01542 Barbiturate amidohydrolase {'R02137': {'dG_mean': 21.623870968586203, 'dG_uncer': 2.1279309969365894}}
# rxn01552 GAMMA-GLUTAMYLHISTAMINE-SYNTHASE-RXN.c {'R02152': {'dG_mean': -11.519674678961024, 'dG_uncer': 1.3565710115347362}}
# rxn01553 L-Glutamate:histamine ligase {'R02152': {'dG_mean': -11.519674678961024, 'dG_uncer': 1.3565710115347362}}
# no dG for rxn01569
# no dG for rxn01587
# rxn01591 oxoacyl- and enoyl-reducing) {'R02221': {'dG_mean': -42.691771063811416, 'dG_uncer': 1.6137761739506318}}
# rxn01592 oxoacyl- and enoyl-reducing) {'R02221': {'dG_mean': -42.691771063811416, 'dG_uncer': 1.6137761739506318}}
# rxn01627 Succinyl-CoA:glycine C-succinyl-transferase(decarboxylating) {'R02269': {'dG_mean': -7.907810608087672, 'dG_uncer': 0.1173127864554263}}
# no dG for rxn01659
# no dG for rxn01666
# no dG for rxn01667
# no dG for rxn01668
# rxn01681 rxn01681 {'R02338': {'dG_mean': -358.1209812259831, 'dG_uncer': 2.442929369660453}}
# rxn01691 R_R02351_c {'R02350': {'dG_mean': -32.51113816307904, 'dG_uncer': 2.594125043951262}}
# nan no dG for rxn01700 {'R02365': {'dG_mean': nan, 'dG_uncer': nan}}
# no dG for rxn01736
# rxn01741 rll_57 {'R02413': {'dG_mean': 58.666281204097714, 'dG_uncer': 2.476158854682967}}
# rxn01755 Erythritol:NADP+ oxidoreductase {'R02430': {'dG_mean': -22.801971752886743, 'dG_uncer': 0.996106807913024}}
# no dG for rxn01756
# rxn01766 flavanone,NADPH:oxygen oxidoreductase {'R02442': {'dG_mean': -331.5397369649156, 'dG_uncer': 1.789821702139022}}
# rxn01796 rxn01796 {'R02478': {'dG_mean': -35.64272029475558, 'dG_uncer': 1.6173700595911975}}
# no dG for rxn01810
# no dG for rxn01811
# rxn01829 L-Arabinono-1,5-lactone lactonohydrolase {'R02522': {'dG_mean': -45.6338467918097, 'dG_uncer': 1.0452074111250214}}
# no dG for rxn01844
# no dG for rxn01845
# rxn01852 TOLUENE-SIDE-CHAIN-MONOOXYGENASE-RXN.c {'R02549': {'dG_mean': -20.97241938480539, 'dG_uncer': 0.1355948552253515}}
# rxn01869 R_R02567_c {'R02566': {'dG_mean': -11.668332183414918, 'dG_uncer': 0.5214069713586865}}
# no dG for rxn01871
# no dG for rxn01872
# no dG for rxn01873
# no dG for rxn01890
# no dG for rxn01891
# no dG for rxn01892
# rxn01897 L-2-Amino-4-chloropent-4-enoate chloride-lyase (deaminating) {'R02604': {'dG_mean': 29.604960977774997, 'dG_uncer': 1.448651462362064}}
# rxn01915 urate-ribonucleotide:orthophosphate D-ribosyltransferase {'R02644': {'dG_mean': 20.402161337758127, 'dG_uncer': 2.272341114707226}}
# rxn01923 ACOAD19 {'R02659': {'dG_mean': 37.73135214385076, 'dG_uncer': 2.4372015719262023}}
# rxn01924 MEPROPCOA-FAD-RXN.c {'R02659': {'dG_mean': 37.73135214385076, 'dG_uncer': 2.4372015719262023}}
# no dG for rxn01925
# rxn01932 Hydorogen-peroxide:hydrogen-peroxide oxidoreductase {'R02669': {'dG_mean': -8.060714944642257, 'dG_uncer': 1.294046828528509}}
# rxn01940 indole-3-acetaldehyde:oxygen oxidoreductase {'R02680': {'dG_mean': -12.268756331728738, 'dG_uncer': 1.040204294119135}}
# no dG for rxn01958
# rxn01960 ARAB14LO {'R02714': {'dG_mean': -15.130544816727706, 'dG_uncer': 0.7090677743760713}}
# no dG for rxn01963
# rxn01965 RXN-7875.c {'R02722': {'dG_mean': -31.702580879637623, 'dG_uncer': 0.1485575615176676}}
# no dG for rxn01982
# no dG for rxn01983
# no dG for rxn01988
# no dG for rxn01992
# rxn02001 dTDP-4-dehydro-6-deoxy-D-glucose 3,5-epimerase {'R06514': {'dG_mean': -9.833266797069127, 'dG_uncer': 1.4647843584152185}}
# rxn02005 TREpts {'R02778': {'dG_mean': -12.349403003928757, 'dG_uncer': 0.1252280694986351}, 'R06228': 'no dG'}
# rxn02010 UAAGLS2 {'R02786': {'dG_mean': -18.897711374682245, 'dG_uncer': 1.6386984959430149}}
# rxn02017 11-epi-Prostaglandin F2alpha:NADP+ 11-oxidoreductase {'R02798': {'dG_mean': -72.17491935248083, 'dG_uncer': 2.3763064208684117}}
# no dG for rxn02025
# no dG for rxn02027
# no dG for rxn02030
# no dG for rxn02040
# no dG for rxn02047
# nan no dG for rxn02076 {'R02899': {'dG_mean': nan, 'dG_uncer': nan}}
# rxn02086 Medicarpin:NADP+ 2'-oxidoreductase {'R02914': {'dG_mean': 9.327139211513348, 'dG_uncer': 0.111307704713569}}
# no dG for rxn02101
# rxn02116 R_R02950_c {'R02949': {'dG_mean': 5.119322953084591, 'dG_uncer': 1.137171294823978}}
# rxn02124 naphthalene,NADH:oxygen oxidoreductase (1,2-hydroxylating) {'R02963': {'dG_mean': -20.664321167531117, 'dG_uncer': 1.8831714624937013}}
# rxn02146 rxn02146 {'R02992': {'dG_mean': -99.25841075020384, 'dG_uncer': 1.877443895040935}}
# rxn02152 rxn02152 {'R02999': {'dG_mean': -76.95783372560417, 'dG_uncer': 1.4602762181578428}}
# rxn02162 rll_99 {'R03014': {'dG_mean': -10.385777411529377, 'dG_uncer': 0.1042962466793533}}
# no dG for rxn02195
# no dG for rxn02203
# rxn02205 Ferrocytochrome:nitrate oxidoreductase {'R03070': {'dG_mean': -3.1373990890546626, 'dG_uncer': 0.1436173098139341}}
# rxn02208 UTP:aldose-1-phosphate nucleotidyltransferase {'R03075': {'dG_mean': 32.91750877673043, 'dG_uncer': 1.2920712195770423}}
# rxn02225 rxn02225 {'R03098': {'dG_mean': 57.82642509806797, 'dG_uncer': 1.3368088661490636}}
# rxn02233 rxn02233 {'R03112': {'dG_mean': -96.4958499305634, 'dG_uncer': 3.3347351268533547}}
# no dG for rxn02236
# no dG for rxn02237
# rxn02240 flavanone,NADPH:oxygen oxidoreductase {'R03124': {'dG_mean': -331.54287366213066, 'dG_uncer': 1.789821702139022}}
# no dG for rxn02252
# no dG for rxn02253
# no dG for rxn02254
# rxn02256 NTP:hexose-1-phosphate nucleotidyltransferase {'R03148': {'dG_mean': -507.40277711723655, 'dG_uncer': 2.382065702182831}}
# no dG for rxn02267
# no dG for rxn02268
# rxn02270 2-MEBUCOA-FAD-RXN.c {'R03171': {'dG_mean': -23.80743411114102, 'dG_uncer': 0.6883431204252328}}
# rxn02271 R_R03174_c {'R03171': {'dG_mean': -23.80743411114102, 'dG_uncer': 0.6883431204252328}}
# no dG for rxn02333
# no dG for rxn02334
# no dG for rxn02342
# rxn02368 dechlorinating) {'R03304': {'dG_mean': -96.71134213033726, 'dG_uncer': 3.3347351268533547}}
# no dG for rxn02371
# no dG for rxn02372
# no dG for rxn02376
# no dG for rxn02383
# no dG for rxn02386
# no dG for rxn02387
# no dG for rxn02391
# no dG for rxn02408
# no dG for rxn02409
# no dG for rxn02423
# no dG for rxn02443
# no dG for rxn02450
# no dG for rxn02453
# no dG for rxn02454
# no dG for rxn02462
# rxn02471 2.5.1.36-RXN.c {'R03452': {'dG_mean': -363.4430724773352, 'dG_uncer': 1.5065392906766206}}
# no dG for rxn02486
# no dG for rxn02487
# no dG for rxn02491
# no dG for rxn02492
# no dG for rxn02493
# no dG for rxn02494
# no dG for rxn02495
# rxn02497 Geranoyl-CoA:carbon-dioxide ligase (ADP-forming) {'R03494': {'dG_mean': -20.366885124821465, 'dG_uncer': 1.989456144402616}}
# nan no dG for rxn02524 {'R03541': {'dG_mean': nan, 'dG_uncer': nan}}
# rxn02547 4-Cresol,NADPH:oxogen oxidoreductase (2-hydroxylating) {'R03567': {'dG_mean': 7.807036184384657, 'dG_uncer': 1.0512709310099215}}
# rxn02553 D-Apiitol:NAD+ 1-oxidoreductase {'R03576': {'dG_mean': -14.358435635371391, 'dG_uncer': 0.102352361368536}}
# rxn02570 Hydrogen selenide:NADP+ oxidoreductase {'R03595': {'dG_mean': 178.41418735918106, 'dG_uncer': 2.992155133992986}}
# no dG for rxn02572
# no dG for rxn02573
# no dG for rxn02582
# no dG for rxn02583
# rxn02588 LIMONIN-D-RING-LACTONASE-RXN.c {'R03623': {'dG_mean': -84.95753972697271, 'dG_uncer': 3.274837372299772}}
# no dG for rxn02605
# rxn02613 rxn02613 {'R03675': {'dG_mean': -31.91368397825241, 'dG_uncer': 3.485788536604846}}
# rxn02619 rxn02619 {'R03689': {'dG_mean': 34.63665628702833, 'dG_uncer': 2.623897901975077}}
# rxn02626 rxn02626 {'R03696': {'dG_mean': 5.089232667850297, 'dG_uncer': 0.1207275926536804}}
# no dG for rxn02632
# rxn02644 rxn02644 {'R03723': {'dG_mean': -50.91782579153031, 'dG_uncer': 2.9038419218154505}}
# rxn02648 rxn02648 {'R03728': {'dG_mean': -480.7193126020381, 'dG_uncer': 0.1860288639202894}}
# no dG for rxn02657
# no dG for rxn02658
# rxn02662 rxn02662 {'R03747': {'dG_mean': -12.380602364711764, 'dG_uncer': 0.8112547140566378}}
# rxn02664 rxn02664 {'R03751': {'dG_mean': -11.147459183954112, 'dG_uncer': 0.9179350957292666}}
# rxn02672 rxn02672 {'R03764': {'dG_mean': 7.015418268726535, 'dG_uncer': 1.5224702783081032}}
# no dG for rxn02692
# rxn02701 rxn02701 {'R03810': {'dG_mean': -34.5723558053424, 'dG_uncer': 1.798508917019211}}
# rxn02707 rxn02707 {'R03822': {'dG_mean': -7.036758952006863, 'dG_uncer': 0.9117525314034274}}
# no dG for rxn02714
# nan no dG for rxn02723 {'R03861': {'dG_mean': nan, 'dG_uncer': nan}}
# e no dG for rxn02728 {'R03868': {'dG_mean': -7.871773641454638e-05, 'dG_uncer': 0.1016106817481443}}
# rxn02730 (S)-Methylmalonate semialdehyde:oxygen oxidoreductase {'R03869': {'dG_mean': -4.2283549919224015, 'dG_uncer': 1.6279846509813083}}
# no dG for rxn02731
# no dG for rxn02732
# rxn02736 UDP-L-rhamnose:flavonol-3-O-D-glucoside L-rhamnosyltransferase {'R03879': {'dG_mean': 50.86597326805871, 'dG_uncer': 1.716827720384758}}
# no dG for rxn02757
# no dG for rxn02777
# rxn02792 R_R03971_c {'R03970': {'dG_mean': 4.63917843804839, 'dG_uncer': 1.546615591069532}}
# rxn02793 rxn02793 {'R03970': {'dG_mean': 4.63917843804839, 'dG_uncer': 1.546615591069532}}
# rxn02799 dechloronating) {'R03980': {'dG_mean': -49.69768631277682, 'dG_uncer': 2.594354051429684}}
# rxn02800 (ring-opening, cyclizing) {'R03984': {'dG_mean': 61.2622901974531, 'dG_uncer': 1.5562532015297346}}
# rxn02813 3-Chloro-L-alanine chloride-lyase (adding thioglycolate) {'R04002': {'dG_mean': 8.509903044127839, 'dG_uncer': 1.7336290801909204}}
# no dG for rxn02817
# no dG for rxn02820
# no dG for rxn02821
# rxn02822 R_R04019_c {'R04018': 'no dG', 'R06147': 'no dG'}
# no dG for rxn02822
# no dG for rxn02824
# nan no dG for rxn02825 {'R08386': {'dG_mean': nan, 'dG_uncer': nan}}
# rxn02838 rxn02838 {'R04040': {'dG_mean': 30.41432325274606, 'dG_uncer': 3.7300258911644177}}
# rxn02846 rxn02846 {'R04053': {'dG_mean': 40.01558986103646, 'dG_uncer': 1.19562821655101}}
# no dG for rxn02849
# rxn02856 rxn02856 {'R04068': {'dG_mean': -80.41149375767566, 'dG_uncer': 1.8661569008001035}}
# rxn02859 Aldehyde:oxygen oxidoreductase {'R04084': {'dG_mean': -84.5500437456904, 'dG_uncer': 2.27187554282418}}
# rxn02867 R_R04097_c {'R04095': {'dG_mean': -13.596457770870202, 'dG_uncer': 2.847998144216199}}
# rxn02870 4-Chlorobenzoyl CoA chlorohydrolase {'R04100': {'dG_mean': 36.0842137264825, 'dG_uncer': 1.6012027660585413}}
# rxn02903 geranylgeranyltransferase {'R04154': {'dG_mean': -15.889327963141293, 'dG_uncer': 0.1436849682590001}}
# no dG for rxn02906
# no dG for rxn02918
# no dG for rxn02919
# no dG for rxn02920
# no dG for rxn02921
# no dG for rxn02922
# rxn02950 3M2OPLOXRD {'R04224': {'dG_mean': 18.239230931679515, 'dG_uncer': 2.5695303968997174}}
# rxn02953 (R)-4'-Phosphopantothenate:L-cysteine ligase {'R04229': {'dG_mean': -193.42021132290856, 'dG_uncer': 2.533036916592509}}
# rxn02954 PPNCL2 {'R04229': {'dG_mean': -193.42021132290856, 'dG_uncer': 2.533036916592509}}
# rxn02955 phosphopantothenate-cysteine ligase {'R04229': {'dG_mean': -193.42021132290856, 'dG_uncer': 2.533036916592509}}
# rxn02960 rxn02960 {'R04237': {'dG_mean': 8.020658280489656, 'dG_uncer': 3.1816615344765866}}
# no dG for rxn02963
# no dG for rxn02964
# no dG for rxn02965
# no dG for rxn02966
# no dG for rxn02968
# no dG for rxn02978
# rxn02984 rxn02984 {'R04280': {'dG_mean': -238.5177865461662, 'dG_uncer': 3.417246965625204}}
# rxn02987 3-Hydroxy-3-(4-methylpent-3-en-1-yl)-glutaryl-CoA-lyase {'R04286': {'dG_mean': -86.33115198391562, 'dG_uncer': 0.9156333531663566}}
# rxn02990 (phosphorylationg) {'R04293': {'dG_mean': 167.12819982046835, 'dG_uncer': 3.1836490890069213}}
# no dG for rxn02992
# rxn03006 rxn03006 {'R04326': {'dG_mean': 24.57316765693632, 'dG_uncer': 1.6451971861900865}}
# rxn03028 citrate:N6-acetyl-N6-hydroxy-L-lysine ligase (ADP-forming) {'R04356': {'dG_mean': -6.278435417743722, 'dG_uncer': 1.216599253203391}}
# no dG for rxn03036
# rxn03044 2.1.1.90-RXN.c {'R04383': {'dG_mean': 6.67225331870435, 'dG_uncer': 0.8296688843254276}}
# rxn03053 (+/-)-6-hydroxy-3-oxo-alpha-ionol:NAD+ 4'-oxidoreductase {'R04405': {'dG_mean': -35.236568759098766, 'dG_uncer': 2.360650731104197}}
# rxn03054 rxn03054 {'R04405': {'dG_mean': -35.236568759098766, 'dG_uncer': 2.360650731104197}}
# no dG for rxn03059
# no dG for rxn03077
# no dG for rxn03081
# rxn03083 (C-C-bond-cleaving) {'R04460': {'dG_mean': -243.99975926761996, 'dG_uncer': 1.7674382575236909}}
# no dG for rxn03091
# rxn03096 rxn03096 {'R04487': {'dG_mean': -25.56862484209161, 'dG_uncer': 6.197849350602329}}
# no dG for rxn03099
# no dG for rxn03100
# rxn03102 1-(1-Alkenyl)-sn-glycero-3-phosphocholine acylhydrolase {'R04498': {'dG_mean': 20.481792984862963, 'dG_uncer': 2.141111100962166}}
# rxn03103 rxn03103 {'R04498': {'dG_mean': 20.481792984862963, 'dG_uncer': 2.141111100962166}}
# no dG for rxn03115
# rxn03117 oxidoreductase (N-oxide-forming) {'R04522': {'dG_mean': 2.112387939341289, 'dG_uncer': 3.0524961627941445}}
# no dG for rxn03121
# no dG for rxn03128
# no dG for rxn03132
# rxn03141 UGLDDS2 {'R04573': {'dG_mean': -61.63097365726142, 'dG_uncer': 2.904727585986226}}
# no dG for rxn03151
# rxn03158 glycopeptide alpha-1,3-D-galactosyltransferase {'R04602': {'dG_mean': -457.075064842416, 'dG_uncer': 3.172332294472151}}
# no dG for rxn03162
# no dG for rxn03163
# no dG for rxn03170
# no dG for rxn03171
# no dG for rxn03172
# no dG for rxn03177
# no dG for rxn03178
# no dG for rxn03179
# no dG for rxn03180
# no dG for rxn03183
# no dG for rxn03184
# no dG for rxn03185
# no dG for rxn03186
# no dG for rxn03187
# rxn03189 rxn03189 {'R04666': {'dG_mean': -15.093515302145915, 'dG_uncer': 0.99319696136075}}
# rxn03190 rxn03190 {'R04666': {'dG_mean': -15.093515302145915, 'dG_uncer': 0.99319696136075}}
# no dG for rxn03191
# rxn03197 (side-chain-cleaving) {'R04675': {'dG_mean': -395.2751843589533, 'dG_uncer': 4.139330314594743}}
# no dG for rxn03199
# rxn03209 Monophenol,L-dopa:oxygen oxidoreductase {'R04692': {'dG_mean': 4.286569310614212, 'dG_uncer': 3.690957950418064}}
# rxn03225 rxn03225 {'R04711': {'dG_mean': -84.29122293723954, 'dG_uncer': 10.926744751709538}}
# no dG for rxn03230
# no dG for rxn03232
# rxn03237 dihydroxypteridine triphosphate {'R04734': {'dG_mean': -31.978096698847366, 'dG_uncer': 4.179909292334541}}
# no dG for rxn03255
# rxn03257 rxn03257 {'R04758': {'dG_mean': 11.672492209088915, 'dG_uncer': 1.1004641280709346}}
# rxn03262 rxn03262 {'R04768': {'dG_mean': -132.78290226148306, 'dG_uncer': 4.440423120316737}}
# no dG for rxn03266
# rxn03269 dTDP-6-deoxy-L-mannose:NADP+ 4-oxidoreductase {'R04777': {'dG_mean': -10.423162865889402, 'dG_uncer': 0.7796989928060083}}
# rxn03276 R_R04787_c {'R04785': {'dG_mean': -89.30414996954337, 'dG_uncer': 2.460484983040609}}
# rxn03279 rxn03279 {'R04792': {'dG_mean': 24.21390808780302, 'dG_uncer': 1.834686641269087}}
# no dG for rxn03280
# no dG for rxn03285
# rxn03288 R_R04811_c {'R04810': {'dG_mean': 13.83387589670697, 'dG_uncer': 0.6802697030311837}}
# no dG for rxn03297
# no dG for rxn03298
# no dG for rxn03309
# rxn03318 (11-hydroxylating) {'R04849': {'dG_mean': -25.96295666123072, 'dG_uncer': 2.361868993974693}}
# no dG for rxn03319
# rxn03321 (side-chain-cleaving) {'R04853': {'dG_mean': -377.772037035043, 'dG_uncer': 1.3448999496679863}}
# rxn03322 RXN66-338.c {'R04853': {'dG_mean': -377.772037035043, 'dG_uncer': 1.3448999496679863}}
# rxn03332 rxn03332 {'R04877': {'dG_mean': 46.52819317694346, 'dG_uncer': 3.691773493845566}}
# rxn03348 rxn03348 {'R04895': {'dG_mean': 35.053241685038145, 'dG_uncer': 1.5880794703571872}}
# rxn03349 rxn03349 {'R04895': {'dG_mean': 35.053241685038145, 'dG_uncer': 1.5880794703571872}}
# no dG for rxn03350
# rxn03355 5-Hydroxyindoleacetaldehyde:oxygen oxidoreductase {'R04903': {'dG_mean': -30.35826049224302, 'dG_uncer': 1.8828438006100172}}
# no dG for rxn03357
# no dG for rxn03359
# no dG for rxn03369
# no dG for rxn03370
# no dG for rxn03371
# rxn03376 rxn03376 {'R04932': {'dG_mean': -81.17004284520317, 'dG_uncer': 4.125173720571821}}
# no dG for rxn03377
# rxn03386 rxn03386 {'R04975': {'dG_mean': 85.78293374946918, 'dG_uncer': 4.196025306428011}}
# rxn03387 Bilirubin beta-diglucuronide glucuronosohydrolase {'R04975': {'dG_mean': 85.78293374946918, 'dG_uncer': 4.196025306428011}}
# rxn03398 SHCHCSYNTH-RXN.c {'R04990': {'dG_mean': 37.28117568399925, 'dG_uncer': 3.561614509852157}}
# rxn03399 rxn03399 {'R04990': {'dG_mean': 37.28117568399925, 'dG_uncer': 3.561614509852157}}
# rxn03401 rxn03401 {'R04996': {'dG_mean': -12.37807868636702, 'dG_uncer': 0.7258076924678774}}
# no dG for rxn03404
# no dG for rxn03405
# no dG for rxn03406
# rxn03409 GLNSP3 {'R05032': {'dG_mean': -19.6091069101322, 'dG_uncer': 1.4110809889517253}}
# no dG for rxn03415
# no dG for rxn03417
# no dG for rxn03418
# rxn03420 rxn03420 {'R05046': {'dG_mean': 8.224788093612062, 'dG_uncer': 1.5444153855265554}}
# no dG for rxn03431
# rxn03444 rxn03444 {'R05079': {'dG_mean': 64.10601209099667, 'dG_uncer': 1.895269704306388}}
# no dG for rxn03448
# no dG for rxn03449
# no dG for rxn03450
# no dG for rxn03451
# rxn03454 rxn03454 {'R05097': {'dG_mean': -448.2118945394332, 'dG_uncer': 2.256631376138019}}
# no dG for rxn03457
# no dG for rxn03459
# no dG for rxn03460
# no dG for rxn03461
# no dG for rxn03462
# no dG for rxn03463
# no dG for rxn03464
# no dG for rxn03465
# no dG for rxn03466
# no dG for rxn03467
# no dG for rxn03480
# no dG for rxn03503
# no dG for rxn03509
# rxn03515 enoyl-reducing and thioester-hydrolysing) {'R05181': {'dG_mean': 178.31976148935684, 'dG_uncer': 5.566069693880304}}
# no dG for rxn03517
# no dG for rxn03518
# rxn03520 rxn03520 {'R05202': {'dG_mean': 57.45220144905335, 'dG_uncer': 4.318005262584972}}
# rxn03521 rxn03521 {'R05202': {'dG_mean': 57.45220144905335, 'dG_uncer': 4.318005262584972}}
# rxn03522 rxn03522 {'R05202': {'dG_mean': 57.45220144905335, 'dG_uncer': 4.318005262584972}}
# rxn03524 Mercaptoethanol:cyanide sulfurtransferase {'R05207': {'dG_mean': -1.5642895836860191, 'dG_uncer': 1.7226925518518483}}
# rxn03533 cob(II)yrinic acid-a,c-diamide:FMN oxidoreductase {'R05217': {'dG_mean': -214.38959905488696, 'dG_uncer': 3.7417541411245057}}
# rxn03539 rxn03539 {'R05223': {'dG_mean': 368.5894541072584, 'dG_uncer': 7.74127140033905}}
# rxn03542 hydrogenobyrinic-acid-a,c-diamide:cobalt cobalt-ligase (ADP-forming) {'R05227': {'dG_mean': -19.214994600920303, 'dG_uncer': 2.5346851297489}}
# rxn03543 Penicillin-N,2-oxoglutarate:oxygen oxidoreductase (ring-expanding) {'R05227': {'dG_mean': -19.214994600920303, 'dG_uncer': 2.5346851297489}}
# rxn03548 rxn03548 {'R05232': {'dG_mean': 20.84352265381732, 'dG_uncer': 0.1097459987281142}}
# rxn03549 rxn03549 {'R05232': {'dG_mean': 20.84352265381732, 'dG_uncer': 0.1097459987281142}}
# rxn03553 ADPglucose:sn-glycerol-3-phosphate 2-beta-D-glucosyltransferase {'R05237': {'dG_mean': -70.70371199965454, 'dG_uncer': 1.2858184192463868}}
# rxn03572 R_R05259_c {'R05258': {'dG_mean': 421.3357545233317, 'dG_uncer': 4.325256573956689}}
# rxn03579 rxn03579 {'R05266': {'dG_mean': -393.222223879988, 'dG_uncer': 1.6076515843886412}}
# no dG for rxn03597
# no dG for rxn03616
# no dG for rxn03628
# no dG for rxn03629
# rxn03645 rxn03645 {'R05339': {'dG_mean': -15.25587217903596, 'dG_uncer': 0.116830349217805}}
# no dG for rxn03647
# no dG for rxn03648
# rxn03656 rxn03656 {'R05354': {'dG_mean': 92.14779377870386, 'dG_uncer': 3.793821890500301}}
# rxn03664 rxn03664 {'R05362': {'dG_mean': 18.27601050138543, 'dG_uncer': 2.298006578154261}}
# rxn03672 trans-3-Chloroacrylic acid chlorohydrolase {'R05370': {'dG_mean': 65.97891554233486, 'dG_uncer': 1.8555905311538436}}
# rxn03673 cis-3-Chloroacrylic acid chlorohydrolase {'R05370': {'dG_mean': 65.97891554233486, 'dG_uncer': 1.8555905311538436}}
# rxn03689 5-Chloro-1,2,4-trihydroxybenzene chloride-lyase {'R05387': {'dG_mean': -30.46540577587467, 'dG_uncer': 3.3105910628447845}}
# rxn03692 rxn03692 {'R05390': {'dG_mean': 80.31532395365213, 'dG_uncer': 3.28304308163097}}
# rxn03718 rxn03718 {'R05417': {'dG_mean': -369.87454433944873, 'dG_uncer': 3.509589036290928}}
# rxn03719 RXN-9863.c {'R05419': {'dG_mean': -434.977315120284, 'dG_uncer': 1.607191773376286}}
# rxn03722 rxn03722 {'R05421': {'dG_mean': -70.09440208484939, 'dG_uncer': 2.4135877747784145}}
# rxn03723 RXN-2482.c {'R05421': {'dG_mean': -70.09440208484939, 'dG_uncer': 2.4135877747784145}}
# rxn03725 rxn03725 {'R05424': {'dG_mean': -34.41028174304266, 'dG_uncer': 1.756476178816343}}
# rxn03726 rxn03726 {'R05424': {'dG_mean': -34.41028174304266, 'dG_uncer': 1.756476178816343}}
# no dG for rxn03757
# no dG for rxn03759
# no dG for rxn03760
# no dG for rxn03761
# no dG for rxn03767
# no dG for rxn03768
# no dG for rxn03769
# no dG for rxn03770
# no dG for rxn03771
# no dG for rxn03776
# no dG for rxn03777
# rxn03784 rxn03784 {'R05487': {'dG_mean': -392.1366584497855, 'dG_uncer': 1.1156294821007973}}
# rxn03802 rxn03802 {'R05511': {'dG_mean': -57.729214536783445, 'dG_uncer': 2.3102443064792246}}
# rxn03803 rxn03803 {'R05511': {'dG_mean': -57.729214536783445, 'dG_uncer': 2.3102443064792246}}
# rxn03812 rxn04287 {'R05522': {'dG_mean': -402.8064697540569, 'dG_uncer': 1.6270340167878363}}
# rxn03813 rxn03813 {'R05522': {'dG_mean': -402.8064697540569, 'dG_uncer': 1.6270340167878363}}
# rxn03815 rxn03815 {'R06427': {'dG_mean': 31.881454691711525, 'dG_uncer': 6.017171744544368}}
# rxn03817 rxn03817 {'R05527': {'dG_mean': 5.833008698495377, 'dG_uncer': 1.0570092350491846}}
# rxn03818 rxn03818 {'R05527': {'dG_mean': 5.833008698495377, 'dG_uncer': 1.0570092350491846}}
# rxn03826 rxn885_c {'R05536': {'dG_mean': 129.12867834625442, 'dG_uncer': 3.892820391762824}}
# rxn03828 rxn03828 {'R05538': {'dG_mean': 119.7143934843033, 'dG_uncer': 2.0887559718519157}}
# rxn03834 rxn03834 {'R05544': {'dG_mean': 75.32573794612077, 'dG_uncer': 2.853611270430316}}
# rxn03844 Atrazine chlorohydrolase {'R05555': {'dG_mean': -97.18047640381728, 'dG_uncer': 3.697440979511283}}
# rxn03857 rxn03857 {'R05571': {'dG_mean': 40.69605640516511, 'dG_uncer': 1.1768875737771425}}
# no dG for rxn03862
# rxn03890 rxn03890 {'R05610': {'dG_mean': -62.80581049547243, 'dG_uncer': 2.0160716985498155}}
# rxn03902 PAPPT1 {'R05627': {'dG_mean': -24.42773570105328, 'dG_uncer': 0.1021136723263912}}
# no dG for rxn03905
# rxn03931 R503-RXN.c {'R05658': {'dG_mean': 45.63720359750204, 'dG_uncer': 1.464508268108623}}
# no dG for rxn03932
# no dG for rxn03937
# rxn03939 rxn03939 {'R05668': {'dG_mean': -1.0194632266564554, 'dG_uncer': 1.40384052182943}}
# no dG for rxn03940
# no dG for rxn03941
# no dG for rxn03945
# rxn03965 Nucleoside:oxygen 5'-oxidoreductase (H2O2-forming) {'R05694': {'dG_mean': 19.13632331090109, 'dG_uncer': 0.3870215478601492}}
# rxn03967 rxn03967 {'R05696': {'dG_mean': -104.27645633258764, 'dG_uncer': 0.7480497678162202}}
# rxn03977 N,N-dimethyl-1,4-phenylenediamine, aniline:NADP+ oxidoreductase {'R05707': {'dG_mean': 18.533420875865914, 'dG_uncer': 0.1447992966523419}}
# no dG for rxn03978
# no dG for rxn03985
# no dG for rxn03986
# rxn03987 chloride:oxygen oxidoreductase {'R05718': {'dG_mean': -91.37748549384456, 'dG_uncer': 2.406099599955608}}
# rxn03999 oxidoreductase (hydroxylating) {'R05733': {'dG_mean': -441.65262194580976, 'dG_uncer': 2.7270298714256973}}
# no dG for rxn04035
# no dG for rxn04044
# rxn04046 RXN-8760.c {'R05807': {'dG_mean': 3.107485764787498, 'dG_uncer': 1.0346259853267954}}
# rxn04053 rxn04053 {'R05814': {'dG_mean': 92.81952979975392, 'dG_uncer': 6.6222020352888045}}
# rxn04055 rxn04055 {'R05821': {'dG_mean': -456.8925848407097, 'dG_uncer': 0.6968162134994053}}
# rxn04072 rxn04072 {'R05839': {'dG_mean': 1.1432981798500244, 'dG_uncer': 0.1617568306538661}}
# rxn04075 rxn04075 {'R05842': {'dG_mean': 34.72970090214895, 'dG_uncer': 3.126900243455608}}
# no dG for rxn04084
# no dG for rxn04085
# no dG for rxn04090
# no dG for rxn04091
# no dG for rxn04098
# no dG for rxn04099
# no dG for rxn04100
# no dG for rxn04102
# no dG for rxn04103
# no dG for rxn04115
# no dG for rxn04116
# no dG for rxn04117
# no dG for rxn04118
# no dG for rxn04119
# no dG for rxn04120
# no dG for rxn04121
# no dG for rxn04122
# no dG for rxn04123
# no dG for rxn04124
# no dG for rxn04125
# no dG for rxn04126
# no dG for rxn04127
# no dG for rxn04128
# no dG for rxn04129
# no dG for rxn04138
# no dG for rxn04144
# no dG for rxn04145
# no dG for rxn04146
# rxn04155 rxn04155 {'R06267': {'dG_mean': -513.1819503115646, 'dG_uncer': 4.454039796177379}}
# rxn04156 rxn04156 {'R06267': {'dG_mean': -513.1819503115646, 'dG_uncer': 4.454039796177379}}
# rxn04157 rxn04157 {'R06267': {'dG_mean': -513.1819503115646, 'dG_uncer': 4.454039796177379}}
# nan no dG for rxn04160 {'R06282': {'dG_mean': nan, 'dG_uncer': nan}}
# no dG for rxn04163
# no dG for rxn04187
# no dG for rxn04188
# no dG for rxn04189
# no dG for rxn04190
# no dG for rxn04191
# no dG for rxn04192
# no dG for rxn04193
# no dG for rxn04194
# no dG for rxn04197
# no dG for rxn04199
# no dG for rxn04200
# no dG for rxn04201
# no dG for rxn04202
# no dG for rxn04203
# no dG for rxn04204
# no dG for rxn04205
# no dG for rxn04206
# no dG for rxn04207
# no dG for rxn04212
# no dG for rxn04213
# no dG for rxn04214
# no dG for rxn04220
# no dG for rxn04221
# no dG for rxn04223
# no dG for rxn04225
# no dG for rxn04226
# no dG for rxn04231
# no dG for rxn04232
# no dG for rxn04233
# rxn04235 perillic acid:CoA ligase (ADP-forming) {'R06367': {'dG_mean': -28.579183452603445, 'dG_uncer': 1.6207004636478048}}
# rxn04236 perillic acid:CoA ligase (AMP-forming) {'R06368': {'dG_mean': -36.65793954009706, 'dG_uncer': 1.620708748541538}}
# no dG for rxn04239
# rxn04258 rxn04258 {'R06391': {'dG_mean': 3.3528913089477115, 'dG_uncer': 1.4965165221032728}}
# no dG for rxn04263
# rxn04267 R_R06404_c {'R06400': {'dG_mean': -366.6380930512309, 'dG_uncer': 1.8702894292990009}}
# rxn04272 cis-2-Methyl-5-isopropylhexa-2,5-dienoate-CoA ligase {'R06408': {'dG_mean': -0.0960197786863545, 'dG_uncer': 1.8409720785320964}}
# rxn04273 trans-2-Methyl-5-isopropylhexa-2,5-dienoate-CoA ligase {'R06408': {'dG_mean': -0.0960197786863545, 'dG_uncer': 1.8409720785320964}}
# rxn04279 (-)-Isopiperitenone reductase {'R06415': {'dG_mean': -29.80375708829845, 'dG_uncer': 1.515856434359715}}
# no dG for rxn04286
# rxn04287 rxn04287 {'R06423': {'dG_mean': 2.438759644832359, 'dG_uncer': 1.0387102960417152}}
# no dG for rxn04289
# rxn04293 rxn04293 {'R06430': {'dG_mean': -9.542598304007017, 'dG_uncer': 0.9487789801645244}}
# rxn04304 rxn04304 {'R06441': {'dG_mean': 59.6064208935441, 'dG_uncer': 1.3987678327178874}}
# no dG for rxn04306
# rxn04309 rxn04309 {'R06447': {'dG_mean': -775.1831310182099, 'dG_uncer': 25.50720379655659}}
# rxn04310 rxn04310 {'R06447': {'dG_mean': -775.1831310182099, 'dG_uncer': 25.50720379655659}}
# rxn04319 rxn04319 {'R06457': {'dG_mean': -50.11320628831486, 'dG_uncer': 1.8434938758771648}}
# rxn04320 rxn04320 {'R06457': {'dG_mean': -50.11320628831486, 'dG_uncer': 1.8434938758771648}}
# rxn04341 rxn04341 {'R06479': {'dG_mean': -52.92505806822386, 'dG_uncer': 4.76914981927755}}
# rxn04342 rxn04342 {'R06479': {'dG_mean': -52.92505806822386, 'dG_uncer': 4.76914981927755}}
# rxn04343 rxn04343 {'R06479': {'dG_mean': -52.92505806822386, 'dG_uncer': 4.76914981927755}}
# rxn04344 rxn04344 {'R06479': {'dG_mean': -52.92505806822386, 'dG_uncer': 4.76914981927755}}
# rxn04361 rxn04361 {'R06499': {'dG_mean': -12.012446176092226, 'dG_uncer': 3.2513753063417554}}
# no dG for rxn04364
# no dG for rxn04365
# no dG for rxn04366
# rxn04369 rxn04369 {'R06510': {'dG_mean': 261.7430799233286, 'dG_uncer': 2.903793529836072}}
# rxn04370 rxn04370 {'R06510': {'dG_mean': 261.7430799233286, 'dG_uncer': 2.903793529836072}}
# rxn04374 R_R06516_c {'R06515': {'dG_mean': -8.671290886364432, 'dG_uncer': 1.9956854406748967}}
# no dG for rxn04375
# no dG for rxn04378
# rxn04380 S-adenosyl-L-methionine:homoprotocatechuate O-methyltransferase {'R06523': {'dG_mean': -118.89727270157344, 'dG_uncer': 5.180851104408155}}
# no dG for rxn04381
# no dG for rxn04382
# no dG for rxn04383
# rxn04396 R_R06541_c {'R06540': {'dG_mean': -532.3322405718195, 'dG_uncer': 1.6778271724967844}}
# rxn04397 R_R06542_c {'R06540': {'dG_mean': -532.3322405718195, 'dG_uncer': 1.6778271724967844}}
# rxn04398 R_R06543_c {'R06540': {'dG_mean': -532.3322405718195, 'dG_uncer': 1.6778271724967844}}
# rxn04399 rxn04399 {'R06540': {'dG_mean': -532.3322405718195, 'dG_uncer': 1.6778271724967844}}
# rxn04400 rxn04400 {'R06540': {'dG_mean': -532.3322405718195, 'dG_uncer': 1.6778271724967844}}
# rxn04401 rxn04401 {'R06540': {'dG_mean': -532.3322405718195, 'dG_uncer': 1.6778271724967844}}
# no dG for rxn04403
# no dG for rxn04404
# no dG for rxn04405
# rxn04407 rxn04407 {'R06551': {'dG_mean': -421.5533787031636, 'dG_uncer': 4.574835480200089}}
# rxn04410 rxn04410 {'R06554': {'dG_mean': -4.596240480002308, 'dG_uncer': 4.279950235919387}}
# rxn04412 flavanone,NADPH:oxygen oxidoreductase {'R06556': {'dG_mean': 29.26604095311422, 'dG_uncer': 2.8810599960884145}}
# rxn04414 flavanone,NADPH:oxygen oxidoreductase {'R06558': {'dG_mean': -11.953519784702223, 'dG_uncer': 0.8555736012575395}}
# rxn04420 rxn04420 {'R06564': {'dG_mean': -93.98122399352464, 'dG_uncer': 3.4249789497515133}}
# rxn04421 rxn04421 {'R06564': {'dG_mean': -93.98122399352464, 'dG_uncer': 3.4249789497515133}}
# rxn04422 R_R06568_c {'R06564': {'dG_mean': -93.98122399352464, 'dG_uncer': 3.4249789497515133}}
# no dG for rxn04433
# no dG for rxn04434
# no dG for rxn04435
# no dG for rxn04436
# no dG for rxn04438
# no dG for rxn04440
# no dG for rxn04450
# no dG for rxn04452
# rxn04460 rxn04460 {'R06607': {'dG_mean': -302.0065895797735, 'dG_uncer': 1.810197789045945}}
# rxn04461 rxn04461 {'R06607': {'dG_mean': -302.0065895797735, 'dG_uncer': 1.810197789045945}}
# no dG for rxn04467
# no dG for rxn04469
# no dG for rxn04470
# rxn04481 rxn04481 {'R06631': {'dG_mean': 4.118372037746379, 'dG_uncer': 0.8956011049571405}}
# no dG for rxn04484
# no dG for rxn04486
# no dG for rxn04487
# no dG for rxn04488
# no dG for rxn04489
# no dG for rxn04490
# no dG for rxn04491
# no dG for rxn04492
# no dG for rxn04493
# rxn04495 rxn04495 {'R06659': {'dG_mean': -37.77649147824426, 'dG_uncer': 1.431606519469704}}
# no dG for rxn04496
# no dG for rxn04497
# no dG for rxn04498
# no dG for rxn04499
# rxn04503 rxn04503 {'R06667': {'dG_mean': 12.027050746913815, 'dG_uncer': 3.833562057883317}}
# rxn04504 rxn04504 {'R06667': {'dG_mean': 12.027050746913815, 'dG_uncer': 3.833562057883317}}
# no dG for rxn04505
# no dG for rxn04506
# no dG for rxn04507
# no dG for rxn04508
# no dG for rxn04509
# no dG for rxn04530
# no dG for rxn04533
# no dG for rxn04534
# no dG for rxn04536
# no dG for rxn04537
# no dG for rxn04538
# no dG for rxn04539
# no dG for rxn04540
# no dG for rxn04541
# no dG for rxn04542
# no dG for rxn04543
# no dG for rxn04544
# no dG for rxn04546
# rxn04548 rxn04548 {'R06715': {'dG_mean': -40.54986296260851, 'dG_uncer': 2.97183907650209}}
# rxn04552 rxn04552 {'R06719': {'dG_mean': -9.93555032236484, 'dG_uncer': 3.30357868580831}, 'R10404': 'no dG'}
# no dG for rxn04553
# no dG for rxn04554
# no dG for rxn04555
# no dG for rxn04556
# no dG for rxn04557
# no dG for rxn04558
# no dG for rxn04562
# no dG for rxn04563
# rxn04566 R_R06735_c {'R06734': {'dG_mean': 2.282515366908086, 'dG_uncer': 0.7946421686176053}}
# rxn04567 R_R06736_c {'R06734': {'dG_mean': 2.282515366908086, 'dG_uncer': 0.7946421686176053}}
# no dG for rxn04568
# no dG for rxn04569
# no dG for rxn04570
# no dG for rxn04572
# no dG for rxn04573
# no dG for rxn04575
# no dG for rxn04576
# no dG for rxn04581
# no dG for rxn04582
# no dG for rxn04583
# no dG for rxn04591
# rxn04594 rxn04594 {'R06778': {'dG_mean': -16.584906699818134, 'dG_uncer': 7.383740301719742}}
# no dG for rxn04595
# no dG for rxn04596
# no dG for rxn04605
# no dG for rxn04606
# no dG for rxn04613
# no dG for rxn04637
# no dG for rxn04638
# no dG for rxn04640
# no dG for rxn04652
# rxn04655 2-chloro-2,5-dihydro-5-oxofuran-2-acetate lyase (decyclizing) {'R06839': {'dG_mean': -544.0707787549923, 'dG_uncer': 3.2246842136840668}}
# no dG for rxn04656
# no dG for rxn04657
# no dG for rxn04658
# no dG for rxn04659
# no dG for rxn04660
# rxn04665 rxn04665 {'R06849': {'dG_mean': 53.896767617269575, 'dG_uncer': 0.116783772412904}}
# rxn04670 rxn04670 {'R06854': {'dG_mean': 12.75115746918638, 'dG_uncer': 1.9704002983523936}}
# rxn04675 R06860_c {'R06859': {'dG_mean': 51.36406295644349, 'dG_uncer': 3.7952447759064354}}
# no dG for rxn04679
# no dG for rxn04689
# no dG for rxn04690
# no dG for rxn04696
# no dG for rxn04698
# no dG for rxn04709
# no dG for rxn04710
# no dG for rxn04738
# no dG for rxn04747
# no dG for rxn04764
# no dG for rxn04768
# rxn04773 rxn04773 {'R06963': {'dG_mean': -37.87132050080761, 'dG_uncer': 3.641170723064563}}
# rxn04774 RXNBWI-7189.c {'R06963': {'dG_mean': -37.87132050080761, 'dG_uncer': 3.641170723064563}}
# rxn04775 ethylaminohydrolase {'R06963': {'dG_mean': -37.87132050080761, 'dG_uncer': 3.641170723064563}}
# no dG for rxn04790
# no dG for rxn04798
# no dG for rxn04799
# no dG for rxn04801
# no dG for rxn04802
# no dG for rxn04812
# no dG for rxn04813
# no dG for rxn04814
# no dG for rxn04815
# no dG for rxn04825
# no dG for rxn04835
# no dG for rxn04837
# rxn04897 2-(S-Glutathionyl)acetyl chloride:glutathione R-transferase {'R07093': {'dG_mean': -29.39388996901356, 'dG_uncer': 2.0139115296360903}}
# rxn04899 rxn04899 {'R07095': {'dG_mean': 49.46163991425851, 'dG_uncer': 1.3429713216409442}}
# rxn04900 rxn04900 {'R07095': {'dG_mean': 49.46163991425851, 'dG_uncer': 1.3429713216409442}}
# no dG for rxn04906
# no dG for rxn04917
# no dG for rxn04918
# no dG for rxn04921
# no dG for rxn04922
# no dG for rxn04929
# no dG for rxn04946
# no dG for rxn04970
# no dG for rxn04993
# rxn05017 and enoyl-reducing, thioester-hydrolysing) {'R07250': {'dG_mean': -7.126519223752439, 'dG_uncer': 4.553541617987247}}
# rxn05019 oxoacyl-reducing, thioester-hydrolysing and cyclizing) {'R07252': {'dG_mean': -3.775638278319377, 'dG_uncer': 1.3672362268370135}}
# rxn05020 malonyl-CoA:4-coumaroyl-CoA malonyltransferase (cyclizing, reducing) {'R07252': {'dG_mean': -3.775638278319377, 'dG_uncer': 1.3672362268370135}}
# no dG for rxn05027
# no dG for rxn05050
# no dG for rxn05063
# no dG for rxn05075
# no dG for rxn05076
# no dG for rxn05077
# no dG for rxn05079
# no dG for rxn05083
# rxn05086 dicarboxylate:oxygen oxidoreductase (cyclizing) {'R07346': {'dG_mean': 12.63572450865513, 'dG_uncer': 0.1187665110389254}}
# no dG for rxn05089
# no dG for rxn05121
# no dG for rxn05133
# no dG for rxn05134
# no dG for rxn05139
# rxn05144 R_PYDXS {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05145 3.6.3.27-RXN.ce {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05146 3.6.3.21-RXN.ce.metaexp.GLT_GLT {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05147 GLCabc {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05148 HEMEti {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05149 3.6.3.35-RXN.ce {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05150 ZNabc {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05151 3.6.3.21-RXN.ce.metaexp.LYS_LYS {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05152 3.6.3.21-RXN.ce.metaexp.L-ASPARTATE_L-ASPARTATE {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05153 3.6.3.25-RXN.ce {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05154 3.6.3.21-RXN.ce.metaexp.ARG_ARG {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05155 3.6.3.21-RXN.ce.metaexp.GLN_GLN {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05156 ORNabc {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05157 Urea-ABC transport {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05158 3.6.3.20-RXN.ce {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05159 CHLabc {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05160 3.6.3.17-RXN.ce.metaexp.CPD-10330_CPD-10330 {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05161 3.6.3.22-RXN.ce.metaexp.LEU_LEU {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05162 GALabc {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05163 PTRCabc {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05164 3.6.3.21-RXN.ce.metaexp.HIS_HIS {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05165 3.6.3.22-RXN.ce.metaexp.PRO_PRO {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05166 RXNBWI-115367.ce {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05167 XYLabc {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05168 3.6.3.22-RXN.ce.metaexp.VAL_VAL {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05169 3.6.3.21-RXN.ce.metaexp.THR_THR {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05170 TRANS-RXNAVI-26732.ce.brachyexp.CPD-3609_CPD-3609 {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05171 3.6.3.26-RXN.ce {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05172 3.6.3.36-RXN.ce {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05173 ARBabc {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05174 NIabc {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05175 SPMDabc {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05176 TSULabc {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05177 THMabc {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05178 D-Aspartate-ABC transport {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05179 3.6.3.22-RXN.ce.metaexp.ILE_ILE {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05180 CRNabc {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# rxn05181 GLYBabc {'R07456': {'dG_mean': -316.4191923769287, 'dG_uncer': 2.747807212880021}}
# ...
# no dG for rxn60015
# no dG for rxn60016
# no dG for rxn60017
# no dG for rxn60018
# no dG for rxn60019
# no dG for rxn60020
# no dG for rxn60021
# no dG for rxn60022
# no dG for rxn60023
# no dG for rxn60024
# no dG for rxn60025
# no dG for rxn60026
# no dG for rxn60027
# no dG for rxn60028
# no dG for rxn60029
# no dG for rxn60030
# no dG for rxn60031
# no dG for rxn60032
# no dG for rxn60033
# no dG for rxn60034
# no dG for rxn60035
# no dG for rxn60036
# no dG for rxn60037
# no dG for rxn60038
# no dG for rxn60039
# no dG for rxn60040
# no dG for rxn60041
# no dG for rxn60042
# no dG for rxn60043
# no dG for rxn60044
# no dG for rxn60045
# no dG for rxn60046
# no dG for rxn60047
# no dG for rxn60048
# no dG for rxn60049
# no dG for rxn60050
# no dG for rxn60051
# no dG for rxn60052
# no dG for rxn60053
# no dG for rxn60054
# no dG for rxn60055
# no dG for rxn60056
# no dG for rxn60057
# no dG for rxn60058
# no dG for rxn60059
# no dG for rxn60060
# no dG for rxn60061
# no dG for rxn60062
# no dG for rxn60063
# no dG for rxn60064
# no dG for rxn60065
# no dG for rxn60066
# no dG for rxn60067
# no dG for rxn60068
# no dG for rxn60069
# no dG for rxn60070
# no dG for rxn60071
# no dG for rxn60072
# no dG for rxn60073
# no dG for rxn60074
# no dG for rxn60075
# no dG for rxn60076
# no dG for rxn60077
# no dG for rxn60078
# no dG for rxn60079
# no dG for rxn60080
# no dG for rxn60081
# no dG for rxn60082
# no dG for rxn60083
# no dG for rxn60084
# no dG for rxn60085
# no dG for rxn60086
# no dG for rxn60087
# no dG for rxn60088
# no dG for rxn60089
# no dG for rxn60090
# no dG for rxn60091
# no dG for rxn60092
# no dG for rxn60093
# no dG for rxn60094
# no dG for rxn60095
# no dG for rxn60096
# no dG for rxn60097
# no dG for rxn60098
# no dG for rxn60099
# no dG for rxn60100
# no dG for rxn60101
# no dG for rxn60102
# no dG for rxn60103
# no dG for rxn60104
# no dG for rxn60105
# no dG for rxn60106
# no dG for rxn60107
# no dG for rxn60108
# no dG for rxn60109
# no dG for rxn60110
# no dG for rxn60111
# no dG for rxn60112
# no dG for rxn60113
# no dG for rxn60114
# no dG for rxn60115
# no dG for rxn60116
# no dG for rxn60117
# no dG for rxn60118
# no dG for rxn60119
# no dG for rxn60120
# no dG for rxn60121
# no dG for rxn60122
# no dG for rxn60123
# no dG for rxn60124
# no dG for rxn60125
# no dG for rxn60126
# no dG for rxn60127
# no dG for rxn60128
# no dG for rxn60129
# no dG for rxn60130
# no dG for rxn60131
# no dG for rxn60132
# no dG for rxn60133
# no dG for rxn60134
# no dG for rxn60135
# no dG for rxn60136
# no dG for rxn60137
# no dG for rxn60138
# no dG for rxn60139
# no dG for rxn60140
# no dG for rxn60141
# no dG for rxn60142
# no dG for rxn60143
# no dG for rxn60144
# no dG for rxn60145
# no dG for rxn60146
# no dG for rxn60147
# no dG for rxn60148
# no dG for rxn60149
# no dG for rxn60150
# no dG for rxn60151
# no dG for rxn60152
# no dG for rxn60153
# no dG for rxn60154
# no dG for rxn60155
# no dG for rxn60156
# no dG for rxn60157
# no dG for rxn60158
# no dG for rxn60159
# no dG for rxn60160
# no dG for rxn60161
# no dG for rxn60162
# no dG for rxn60163
# no dG for rxn60164
# no dG for rxn60165
# no dG for rxn60166
# no dG for rxn60167
# no dG for rxn60168
# no dG for rxn60169
# no dG for rxn60170
# no dG for rxn60171
# no dG for rxn60172
# no dG for rxn60173
# no dG for rxn60174
# no dG for rxn60175
# no dG for rxn60176
# no dG for rxn60177
# no dG for rxn60178
# no dG for rxn60179
# no dG for rxn60180
# no dG for rxn60181
# no dG for rxn60182
# no dG for rxn60183
# no dG for rxn60184
# no dG for rxn60185
# no dG for rxn60186
# no dG for rxn60187
# no dG for rxn60188
# no dG for rxn60189
# no dG for rxn60190
# no dG for rxn60191
# no dG for rxn60192
# no dG for rxn60193
# no dG for rxn60194
# no dG for rxn60195
# no dG for rxn60196
# no dG for rxn60197
# no dG for rxn60198
# no dG for rxn60199
# no dG for rxn60200
# no dG for rxn60201
# no dG for rxn60202
# no dG for rxn60203
# no dG for rxn60204
# no dG for rxn60205
# no dG for rxn60206
# no dG for rxn60207
# no dG for rxn60208
# no dG for rxn60209
# no dG for rxn60210
# no dG for rxn60211
# no dG for rxn60212
# no dG for rxn60213
# no dG for rxn60214
# no dG for rxn60215
# no dG for rxn60216
# no dG for rxn60217
# no dG for rxn60218
# no dG for rxn60219
# no dG for rxn60220
# no dG for rxn60221
# no dG for rxn60222
# no dG for rxn60223
# no dG for rxn60224
# no dG for rxn60225
# no dG for rxn60226
# no dG for rxn60227
# no dG for rxn60228
# no dG for rxn60229
# no dG for rxn60230
# no dG for rxn60231
# no dG for rxn60232
# no dG for rxn60233
# no dG for rxn60234
# no dG for rxn60235
# no dG for rxn60236
# no dG for rxn60237
# no dG for rxn60238
# no dG for rxn60239
# no dG for rxn60240
# no dG for rxn60241
# no dG for rxn60242
# no dG for rxn60243
# no dG for rxn60244
# no dG for rxn60245
# no dG for rxn60246
# no dG for rxn60247
# no dG for rxn60248
# no dG for rxn60249
# no dG for rxn60250
# no dG for rxn60251
# no dG for rxn60252
# no dG for rxn60253
# no dG for rxn60254
# no dG for rxn60255
# no dG for rxn60256
# no dG for rxn60257
# no dG for rxn60258
# no dG for rxn60259
# no dG for rxn60260
# no dG for rxn60261
# no dG for rxn60262
# no dG for rxn60263
# no dG for rxn60264
# no dG for rxn60265
# no dG for rxn60266
# no dG for rxn60267
# no dG for rxn60268
# no dG for rxn60269
# no dG for rxn60270
# no dG for rxn60271
# no dG for rxn60272
# no dG for rxn60273
# no dG for rxn60274
# no dG for rxn60275
# no dG for rxn60276
# no dG for rxn60277
# no dG for rxn60278
# no dG for rxn60279
# no dG for rxn60280
# no dG for rxn60281
# no dG for rxn60282
# no dG for rxn60283
# no dG for rxn60284
# no dG for rxn60285
# no dG for rxn60286
# no dG for rxn60287
# no dG for rxn60288
# no dG for rxn60289
# no dG for rxn60290
# no dG for rxn60291
# no dG for rxn60292
# no dG for rxn60293
# no dG for rxn60294
# no dG for rxn60295
# no dG for rxn60296
# no dG for rxn60297
# no dG for rxn60298
# no dG for rxn60299
# no dG for rxn60300
# no dG for rxn60301
# no dG for rxn60302
# no dG for rxn60303
# no dG for rxn60304
# no dG for rxn60305
# no dG for rxn60306
# no dG for rxn60307
# no dG for rxn60308
# no dG for rxn60309
# no dG for rxn60310
# no dG for rxn60311
# no dG for rxn60312
# no dG for rxn60313
# no dG for rxn60314
# no dG for rxn60315
# no dG for rxn60316
# no dG for rxn60317
# no dG for rxn60318
# no dG for rxn60319
# no dG for rxn60320
# no dG for rxn60321
# no dG for rxn60322
# no dG for rxn60323
# no dG for rxn60324
# no dG for rxn60325
# no dG for rxn60326
# no dG for rxn60327
# no dG for rxn60328
# no dG for rxn60329
# no dG for rxn60330
# no dG for rxn60331
# no dG for rxn60332
# no dG for rxn60333
# no dG for rxn60334
# no dG for rxn60335
# no dG for rxn60336
# no dG for rxn60337
# no dG for rxn60338
# no dG for rxn60339
# no dG for rxn60340
# no dG for rxn60341
# no dG for rxn60342
# no dG for rxn60343
# no dG for rxn60344
# no dG for rxn60345
# no dG for rxn60346
# no dG for rxn60347
# no dG for rxn60348
# no dG for rxn60349
# no dG for rxn60350
# no dG for rxn60351
# no dG for rxn60352
# no dG for rxn60353
# no dG for rxn60354
# no dG for rxn60355
# no dG for rxn60356
# no dG for rxn60357
# no dG for rxn60358
# no dG for rxn60359
# no dG for rxn60360
# no dG for rxn60361
# no dG for rxn60362
# no dG for rxn60363
# no dG for rxn60364
# no dG for rxn60365
# no dG for rxn60366
# no dG for rxn60367
# no dG for rxn60368
# no dG for rxn60369
# no dG for rxn60370
# no dG for rxn60371
# no dG for rxn60372
# no dG for rxn60373
# no dG for rxn60374
# no dG for rxn60375
# no dG for rxn60376
# no dG for rxn60377
# no dG for rxn60378
# no dG for rxn60379
# no dG for rxn60380
# no dG for rxn60381
# no dG for rxn60382
# no dG for rxn60383
# no dG for rxn60384
# no dG for rxn60385
# no dG for rxn60386
# no dG for rxn60387
# no dG for rxn60388
# no dG for rxn60389
# no dG for rxn60390
# no dG for rxn60391
# no dG for rxn60392
# no dG for rxn60393
# no dG for rxn60394
# no dG for rxn60395
# no dG for rxn60396
# no dG for rxn60397
# no dG for rxn60398
# no dG for rxn60399
# no dG for rxn60400
# no dG for rxn60401
# no dG for rxn60402
# no dG for rxn60403
# no dG for rxn60404
# no dG for rxn60405
# no dG for rxn60406
# no dG for rxn60407
# no dG for rxn60408
# no dG for rxn60409
# no dG for rxn60410
# no dG for rxn60411
# no dG for rxn60412
# no dG for rxn60413
# no dG for rxn60414
# no dG for rxn60415
# no dG for rxn60416
# no dG for rxn60417
# no dG for rxn60418
# no dG for rxn60419
# no dG for rxn60420
# no dG for rxn60421
# no dG for rxn60422
# no dG for rxn60423
# no dG for rxn60424
# no dG for rxn60425
# no dG for rxn60426
# no dG for rxn60427
# no dG for rxn60428
# no dG for rxn60429
# no dG for rxn60430
# no dG for rxn60431
# no dG for rxn60432
# no dG for rxn60433
# no dG for rxn60434
# no dG for rxn60435
# no dG for rxn60436
# no dG for rxn60437
# no dG for rxn60438
# no dG for rxn60439
# no dG for rxn60440
# no dG for rxn60441
# no dG for rxn60442
# no dG for rxn60443
# no dG for rxn60444
# no dG for rxn60445
# no dG for rxn60446
# no dG for rxn60447
# no dG for rxn60448
# no dG for rxn60449
# no dG for rxn60450
# no dG for rxn60451
# no dG for rxn60452
# no dG for rxn60453
# no dG for rxn60454
# no dG for rxn60455
# no dG for rxn60456
# no dG for rxn60457
# no dG for rxn60458
# no dG for rxn60459
# no dG for rxn60460
# no dG for rxn60461
# no dG for rxn60462
# no dG for rxn60463
# no dG for rxn60464
# no dG for rxn60465
# no dG for rxn60466
# no dG for rxn60467
# no dG for rxn60468
# no dG for rxn60469
# no dG for rxn60470
# no dG for rxn60471
# no dG for rxn60472
# no dG for rxn60473
# no dG for rxn60474
# no dG for rxn60475
# no dG for rxn60476
# no dG for rxn60477
# no dG for rxn60478
# no dG for rxn60479
# no dG for rxn60480
# no dG for rxn60481
# no dG for rxn60482
# no dG for rxn60483
# no dG for rxn60484
# no dG for rxn60485
# no dG for rxn60486
# no dG for rxn60487
# no dG for rxn60488
# no dG for rxn60489
# no dG for rxn60490
# no dG for rxn60491
# no dG for rxn60492
# no dG for rxn60493
# no dG for rxn60494
# no dG for rxn60495
# no dG for rxn60496
# no dG for rxn60497
# no dG for rxn60498
# no dG for rxn60499
# no dG for rxn60500
# no dG for rxn60501
# no dG for rxn60502
# no dG for rxn60503
# no dG for rxn60504
# no dG for rxn60505
# no dG for rxn60506
# no dG for rxn60507
# no dG for rxn60508
# no dG for rxn60509
# no dG for rxn60510
# no dG for rxn60511
# no dG for rxn60512
# no dG for rxn60513
# no dG for rxn60514
# no dG for rxn60515
# no dG for rxn60516
# no dG for rxn60517
# no dG for rxn60518
# no dG for rxn60519
# no dG for rxn60520
# no dG for rxn60521
# no dG for rxn60522
# no dG for rxn60523
# no dG for rxn60524
# no dG for rxn60525
# no dG for rxn60526
# no dG for rxn60527
# no dG for rxn60528
# no dG for rxn60529
# no dG for rxn60530
# no dG for rxn60531
# no dG for rxn60532
# no dG for rxn60533
# no dG for rxn60534
# no dG for rxn60535
# no dG for rxn60536
# no dG for rxn60537
# no dG for rxn60538
# no dG for rxn60539
# no dG for rxn60540
# no dG for rxn60541
# no dG for rxn60542
# no dG for rxn60543
# no dG for rxn60544
# no dG for rxn60545
# no dG for rxn60546
# no dG for rxn60547
# no dG for rxn60548
# no dG for rxn60549
# no dG for rxn60550
# no dG for rxn60551
# no dG for rxn60552
# no dG for rxn60553
# no dG for rxn60554
# no dG for rxn60555
# no dG for rxn60556
# no dG for rxn60557
# no dG for rxn60558
# no dG for rxn60559
# no dG for rxn60560
# no dG for rxn60561
# no dG for rxn60562
# no dG for rxn60563
# no dG for rxn60564
# no dG for rxn60565
# no dG for rxn60566
# no dG for rxn60567
# no dG for rxn60568
# no dG for rxn60569
# no dG for rxn60570
# no dG for rxn60571
# no dG for rxn60572
# no dG for rxn60573
# no dG for rxn60574
# no dG for rxn60575
# no dG for rxn60576
# no dG for rxn60577
# no dG for rxn60578
# no dG for rxn60579
# no dG for rxn60580
# no dG for rxn60581
# no dG for rxn60582
# no dG for rxn60583
# no dG for rxn60584
# no dG for rxn60585
# no dG for rxn60586
# no dG for rxn60587
# no dG for rxn60588
# no dG for rxn60589
# no dG for rxn60590
# no dG for rxn60591
# no dG for rxn60592
# no dG for rxn60593
# no dG for rxn60594
# no dG for rxn60595
# no dG for rxn60596
# no dG for rxn60597
# no dG for rxn60598
# no dG for rxn60599
# no dG for rxn60600
# no dG for rxn60601
# no dG for rxn60602
# no dG for rxn60603
# no dG for rxn60604
# no dG for rxn60605
# no dG for rxn60606
# no dG for rxn60607
# no dG for rxn60608
# no dG for rxn60609
# no dG for rxn60610
# no dG for rxn60611
# no dG for rxn60612
# no dG for rxn60613
# no dG for rxn60614
# no dG for rxn60615
# no dG for rxn60616
# no dG for rxn60617
# no dG for rxn60618
# no dG for rxn60619
# no dG for rxn60620
# no dG for rxn60621
# no dG for rxn60622
# no dG for rxn60623
# no dG for rxn60624
# no dG for rxn60625
# no dG for rxn60626
# no dG for rxn60627
# no dG for rxn60628
# no dG for rxn60629
# no dG for rxn60630
# no dG for rxn60631
# no dG for rxn60632
# no dG for rxn60633
# no dG for rxn60634
# no dG for rxn60635
# no dG for rxn60636
# no dG for rxn60637
# no dG for rxn60638
# no dG for rxn60639
# no dG for rxn60640
# no dG for rxn60641
# no dG for rxn60642
# no dG for rxn60643
# no dG for rxn60644
# no dG for rxn60645
# no dG for rxn60646
# no dG for rxn60647
# no dG for rxn60648
# no dG for rxn60649
# no dG for rxn60650
# no dG for rxn60651
# no dG for rxn60652
# no dG for rxn60653
# no dG for rxn60654
# no dG for rxn60655
# no dG for rxn60656
# no dG for rxn60657
# no dG for rxn60658
# no dG for rxn60659
# no dG for rxn60660
# no dG for rxn60661
# no dG for rxn60662
# no dG for rxn60663
# no dG for rxn60664
# no dG for rxn60665
# no dG for rxn60666
# no dG for rxn60667
# no dG for rxn60668
# no dG for rxn60669
# no dG for rxn60670
# no dG for rxn60671
# no dG for rxn60672
# no dG for rxn60673
# no dG for rxn60674
# no dG for rxn60675
# no dG for rxn60676
# no dG for rxn60677
# no dG for rxn60678
# no dG for rxn60679
# no dG for rxn60680
# no dG for rxn60681
# no dG for rxn60682
# no dG for rxn60683
# no dG for rxn60684
# no dG for rxn60685
# no dG for rxn60686
# no dG for rxn60687
# no dG for rxn60688
# no dG for rxn60689
# no dG for rxn60690
# no dG for rxn60691
# no dG for rxn60692
# no dG for rxn60693
# no dG for rxn60694
# no dG for rxn60695
# no dG for rxn60696
# no dG for rxn60697
# no dG for rxn60698
# no dG for rxn60699
# no dG for rxn60700
# no dG for rxn60701
# no dG for rxn60702
# no dG for rxn60703
# no dG for rxn60704
# no dG for rxn60705
# no dG for rxn60706
# no dG for rxn60707
# no dG for rxn60708
# no dG for rxn60709
# no dG for rxn60710
# no dG for rxn60711
# no dG for rxn60712
# no dG for rxn60713
# no dG for rxn60714
# no dG for rxn60715
# no dG for rxn60716
# no dG for rxn60717
# no dG for rxn60718
# no dG for rxn60719
# no dG for rxn60720
# no dG for rxn60721
# no dG for rxn60722
# no dG for rxn60723
# no dG for rxn60724
# no dG for rxn60725
# no dG for rxn60726
# no dG for rxn60727
# no dG for rxn60728
# no dG for rxn60729
# no dG for rxn60730
# no dG for rxn60731
# no dG for rxn60732
# no dG for rxn60733
# no dG for rxn60734
# no dG for rxn60735
# no dG for rxn60736
# no dG for rxn60737
# no dG for rxn60738
# no dG for rxn60739
# no dG for rxn60740
# no dG for rxn60741
# no dG for rxn60742
# no dG for rxn60743
# no dG for rxn60744
# no dG for rxn60745
# no dG for rxn60746
# no dG for rxn60747
# no dG for rxn60748
# no dG for rxn60749
# no dG for rxn60750
# no dG for rxn60751
# no dG for rxn60752
# no dG for rxn60753
# no dG for rxn60754
# no dG for rxn60755
# no dG for rxn60756
# no dG for rxn60757
# no dG for rxn60758
# no dG for rxn60759
# no dG for rxn60760
# no dG for rxn60761
# no dG for rxn60762
# no dG for rxn60763
# no dG for rxn60764
# no dG for rxn60765
# no dG for rxn60766
# no dG for rxn60767
# no dG for rxn60768
# no dG for rxn60769
# no dG for rxn60770
# no dG for rxn60771
# no dG for rxn60772
# no dG for rxn60773
# no dG for rxn60774
# no dG for rxn60775
# no dG for rxn60776
# no dG for rxn60777
# no dG for rxn60778
# no dG for rxn60779
# no dG for rxn60780
# no dG for rxn60781
# no dG for rxn60782
# no dG for rxn60783
# no dG for rxn60784
# no dG for rxn60785
# no dG for rxn60786
# no dG for rxn60787
# no dG for rxn60788
# no dG for rxn60789
# no dG for rxn60790
# no dG for rxn60791
# no dG for rxn60792
# no dG for rxn60793
# no dG for rxn60794
# no dG for rxn60795
# no dG for rxn60796
# no dG for rxn60797
# no dG for rxn60798
# no dG for rxn60799
# no dG for rxn60800
# no dG for rxn60801
# no dG for rxn60802
# no dG for rxn60803
# no dG for rxn60804
# no dG for rxn60805
# no dG for rxn60806
# no dG for rxn60807
# no dG for rxn60808
# no dG for rxn60809
# no dG for rxn60810
# no dG for rxn60811
# no dG for rxn60812
# no dG for rxn60813
# no dG for rxn60814
# no dG for rxn60815
# no dG for rxn60816
# no dG for rxn60817
# no dG for rxn60818
# no dG for rxn60819
# no dG for rxn60820
# no dG for rxn60821
# no dG for rxn60822
# no dG for rxn60823
# no dG for rxn60824
# no dG for rxn60825
# no dG for rxn60826
# no dG for rxn60827
# no dG for rxn60828
# no dG for rxn60829
# no dG for rxn60830
# no dG for rxn60831
# no dG for rxn60832
# no dG for rxn60833
# no dG for rxn60834
# no dG for rxn60835
# no dG for rxn60836
# no dG for rxn60837
# no dG for rxn60838
# no dG for rxn60839
# no dG for rxn60840
# no dG for rxn60841
# no dG for rxn60842
# no dG for rxn60843
# no dG for rxn60844
# no dG for rxn60845
# no dG for rxn60846
# no dG for rxn60847
# no dG for rxn60848
# no dG for rxn60849
# no dG for rxn60850
# no dG for rxn60851
# no dG for rxn60852
# no dG for rxn60853
# no dG for rxn60854
# no dG for rxn60855
# no dG for rxn60856

# %%
sorted(list(thermo_values.keys()))
print(len(thermo_values.keys()))
# Out:
# 27694

# %%
from scipy.constants import calorie
for rxnID, content in MSDB_json.items():
    if "deltag" not in MSDB_json[rxnID]:  continue
    parsed_num = re.sub("([0-9\.\-])", "", str(MSDB_json[rxnID]["deltag"]))
    if rxnID not in thermo_values and parsed_num == "":
        MSDB_json[rxnID]["deltag"] = float(MSDB_json[rxnID]["deltag"])
        MSDB_json[rxnID]["deltagerr"] = float(MSDB_json[rxnID]["deltagerr"])
        MSDB_json[rxnID]["deltag"] *= calorie
        MSDB_json[rxnID]["deltagerr"] *= calorie
        continue
    print(rxnID, thermo_values[rxnID])
    MSDB_json[rxnID]["deltag"] = thermo_values[rxnID]["dG_mean"]
    MSDB_json[rxnID]["deltagerr"] = thermo_values[rxnID]["dG_uncer"]
# Out:
# rxn00001 {'dG_mean': -15.978962709842271, 'dG_uncer': 0.1018229252895586}
# rxn00002 {'dG_mean': -96.33065567460018, 'dG_uncer': 1.0434631147207318}
# rxn00003 {'dG_mean': 23.87794947248591, 'dG_uncer': 1.4856033440752583}
# rxn00004 {'dG_mean': -6.199860585711548, 'dG_uncer': 1.4639140224940748}
# rxn00006 {'dG_mean': -194.716885616239, 'dG_uncer': 0.25372185665117}
# rxn00007 {'dG_mean': -12.452251693186184, 'dG_uncer': 0.1081426968520035}
# rxn00008 {'dG_mean': -270.65162982126355, 'dG_uncer': 2.918353088339725}
# rxn00009 {'dG_mean': 1.758495360068423, 'dG_uncer': 0.1146015302373187}
# rxn00010 {'dG_mean': -21.611593067013388, 'dG_uncer': 0.1800158687929662}
# rxn00011 {'dG_mean': -30.62003175875685, 'dG_uncer': 1.81908017782148}
# rxn00012 {'dG_mean': -21.438871437328714, 'dG_uncer': 1.509286832755146}
# rxn00015 {'dG_mean': -19.23769046955533, 'dG_uncer': 2.341528284748625}
# rxn00016 {'dG_mean': 10.518926978742796, 'dG_uncer': 1.389158150064834}
# rxn00017 {'dG_mean': -18.62173462650817, 'dG_uncer': 2.855525951245222}
# rxn00018 {'dG_mean': -36.09110678486431, 'dG_uncer': 0.1531422933954736}
# rxn00019 {'dG_mean': -36.09110678486431, 'dG_uncer': 0.1531422933954736}
# rxn00020 {'dG_mean': 25.66488276842909, 'dG_uncer': 2.045211731693696}
# rxn00021 {'dG_mean': 9.921083638010645, 'dG_uncer': 2.739575176229692}
# rxn00022 {'dG_mean': 24.289307734428377, 'dG_uncer': 2.050717886354702}
# rxn00024 {'dG_mean': -203.72782296345716, 'dG_uncer': 3.5706914095943376}
# rxn00025 {'dG_mean': -304.0765107117736, 'dG_uncer': 4.874642214636745}
# rxn00026 {'dG_mean': -121.62443553018691, 'dG_uncer': 0.5674973827392262}
# rxn00028 {'dG_mean': -322.6679478169682, 'dG_uncer': 6.286457094528829}
# rxn00029 {'dG_mean': -162.9786163689327, 'dG_uncer': 3.113652411743344}
# rxn00030 {'dG_mean': -35.324128139906406, 'dG_uncer': 2.1121961454071485}
# rxn00031 {'dG_mean': 9.89603019707367, 'dG_uncer': 1.2531104413742675}
# rxn00032 {'dG_mean': 9.89603019707367, 'dG_uncer': 1.2531104413742675}
# rxn00033 {'dG_mean': -538.1539452579103, 'dG_uncer': 2.068280876433979}
# rxn00034 {'dG_mean': -259.361908297602, 'dG_uncer': 3.5393089291703217}
# rxn00035 {'dG_mean': -118.5134848997564, 'dG_uncer': 4.036180292720628}
# rxn00036 {'dG_mean': -620.0310043183184, 'dG_uncer': 5.776648052959535}
# rxn00037 {'dG_mean': -620.0310043183184, 'dG_uncer': 5.776648052959535}
# rxn00038 {'dG_mean': -35.994508698624514, 'dG_uncer': 0.9461032020167466}
# rxn00039 {'dG_mean': -45.75164319004346, 'dG_uncer': 1.0995278855043489}
# rxn00040 {'dG_mean': -75.0224676164188, 'dG_uncer': 2.098960065640061}
# rxn00041 {'dG_mean': -76.49456023681607, 'dG_uncer': 2.2459214650889776}
# rxn00042 {'dG_mean': -403.2698001719178, 'dG_uncer': 1.4614409552795968}
# rxn00043 {'dG_mean': -550.0145301337107, 'dG_uncer': 6.804769624356263}
# rxn00044 {'dG_mean': 0.3220302678722788, 'dG_uncer': 1.2010440684029686}
# rxn00045 {'dG_mean': 0.0085922906878295, 'dG_uncer': 0.1016106817481443}
# rxn00046 {'dG_mean': -44.92108988519562, 'dG_uncer': 1.294390686960445}
# rxn00048 {'dG_mean': 58.839374670830736, 'dG_uncer': 6.516833818782413}
# rxn00050 {'dG_mean': 58.839374670830736, 'dG_uncer': 6.516833818782413}
# rxn00051 {'dG_mean': -446.2599388605595, 'dG_uncer': 9.654204644008336}
# rxn00052 {'dG_mean': -145.56933011998268, 'dG_uncer': 0.7049128338919903}
# rxn00053 {'dG_mean': -145.56933011998268, 'dG_uncer': 0.7049128338919903}
# rxn00054 {'dG_mean': -1223.189866692153, 'dG_uncer': 7.054213366831106}
# rxn00055 {'dG_mean': -73.76229438956459, 'dG_uncer': 9.220474767319924}
# rxn00057 {'dG_mean': -907.0040480949036, 'dG_uncer': 11.137144004023044}
# rxn00060 {'dG_mean': -284.5504648608908, 'dG_uncer': 6.577158545248537}
# rxn00061 {'dG_mean': -50.8173349673782, 'dG_uncer': 0.1033826077996765}
# rxn00062 {'dG_mean': -26.759616170042293, 'dG_uncer': 0.102070101081552}
# rxn00063 {'dG_mean': -34.838372257535866, 'dG_uncer': 0.1032394126363634}
# rxn00064 {'dG_mean': -23.64783251929636, 'dG_uncer': 0.1045762377507601}
# rxn00065 {'dG_mean': 7.029234582722779, 'dG_uncer': 0.1072287867113477}
# rxn00066 {'dG_mean': -329.4699329749011, 'dG_uncer': 0.1504289769506442}
# rxn00067 {'dG_mean': 9.824635512929731, 'dG_uncer': 0.2284319565167106}
# rxn00069 {'dG_mean': 50.19199312834854, 'dG_uncer': 0.1062423467626368}
# rxn00070 {'dG_mean': 19.626111649623056, 'dG_uncer': 0.1051766047969921}
# rxn00071 {'dG_mean': 249.95876933579405, 'dG_uncer': 5.216449830607131}
# rxn00072 {'dG_mean': 382.20282752091407, 'dG_uncer': 0.1109804195398385}
# rxn00073 {'dG_mean': 382.20282752091407, 'dG_uncer': 0.1109804195398385}
# rxn00074 {'dG_mean': 65.64001926664241, 'dG_uncer': 0.1032373534648645}
# rxn00075 {'dG_mean': -18.099300482432312, 'dG_uncer': 1.031583345874511}
# rxn00076 {'dG_mean': -34.1086258325779, 'dG_uncer': 0.1160141716170173}
# rxn00077 {'dG_mean': -11.901707039028564, 'dG_uncer': 0.1435540030875839}
# rxn00078 {'dG_mean': -14.342330130876462, 'dG_uncer': 0.1435540030875839}
# rxn00080 {'dG_mean': -379.7622044290665, 'dG_uncer': 0.1109804195398385}
# rxn00081 {'dG_mean': -379.7622044290665, 'dG_uncer': 0.1109804195398385}
# rxn00082 {'dG_mean': -379.7622044290665, 'dG_uncer': 0.1109804195398385}
# rxn00083 {'dG_mean': 2.440623091847897, 'dG_uncer': 0.1016106817481443}
# rxn00084 {'dG_mean': -327.0293098830532, 'dG_uncer': 0.1504289769506442}
# rxn00085 {'dG_mean': 47.751370036500646, 'dG_uncer': 0.1062423467626368}
# rxn00086 {'dG_mean': 17.185488557775273, 'dG_uncer': 0.1051766047969921}
# rxn00087 {'dG_mean': 17.185488557775273, 'dG_uncer': 0.1051766047969921}
# rxn00088 {'dG_mean': -14.85790913101387, 'dG_uncer': 0.1438787550016015}
# rxn00089 {'dG_mean': -10.777019601795956, 'dG_uncer': 0.1808095249281595}
# rxn00090 {'dG_mean': -115.12693570903896, 'dG_uncer': 0.178940655831939}
# rxn00091 {'dG_mean': -115.12693570903896, 'dG_uncer': 0.178940655831939}
# rxn00092 {'dG_mean': -24.057718797335724, 'dG_uncer': 0.1021136723263912}
# rxn00093 {'dG_mean': -23.645778982280845, 'dG_uncer': 0.1045762377507601}
# rxn00095 {'dG_mean': -39.5135374999785, 'dG_uncer': 0.1163235217238457}
# rxn00096 {'dG_mean': 12.75392132993636, 'dG_uncer': 0.115167820530063}
# rxn00097 {'dG_mean': -2.701897372706526, 'dG_uncer': 0.1017525937529222}
# rxn00098 {'dG_mean': -25.41655689270516, 'dG_uncer': 0.102070101081552}
# rxn00099 {'dG_mean': -123.9835316540541, 'dG_uncer': 2.2852086371844305}
# rxn00100 {'dG_mean': 3.601022384478256, 'dG_uncer': 0.1436501693442491}
# rxn00101 {'dG_mean': -30.635425907685075, 'dG_uncer': 0.187072529271532}
# rxn00102 {'dG_mean': 4.747948990619577, 'dG_uncer': 0.1473482513338403}
# rxn00103 {'dG_mean': -14.494378206452616, 'dG_uncer': 0.1519716249425109}
# rxn00104 {'dG_mean': -14.494378206452616, 'dG_uncer': 0.1519716249425109}
# rxn00105 {'dG_mean': -0.7297464249579662, 'dG_uncer': 0.1145050742650224}
# rxn00106 {'dG_mean': -18.767713794833405, 'dG_uncer': 0.102070101081552}
# rxn00107 {'dG_mean': 0.0276619310385513, 'dG_uncer': 0.1016106817481443}
# rxn00108 {'dG_mean': 2.559128738784466, 'dG_uncer': 0.1017525937529222}
# rxn00109 {'dG_mean': 255.0992477985833, 'dG_uncer': 1.9783399707494915}
# rxn00110 {'dG_mean': 255.0992477985833, 'dG_uncer': 1.9783399707494915}
# rxn00111 {'dG_mean': 255.0992477985833, 'dG_uncer': 1.9783399707494915}
# rxn00112 {'dG_mean': 255.0992477985833, 'dG_uncer': 1.9783399707494915}
# rxn00113 {'dG_mean': -0.093756796576585, 'dG_uncer': 0.1700172830942159}
# rxn00114 {'dG_mean': 26.66585937346564, 'dG_uncer': 0.16991804056697}
# rxn00115 {'dG_mean': -73.28970506080626, 'dG_uncer': 0.1556074908924744}
# rxn00116 {'dG_mean': -23.466685919577685, 'dG_uncer': 0.1021136723263912}
# rxn00117 {'dG_mean': -0.9340615605854056, 'dG_uncer': 0.1016106817481443}
# rxn00118 {'dG_mean': -1.7678358121211204, 'dG_uncer': 0.1017525937529222}
# rxn00119 {'dG_mean': -3.2929302504646785, 'dG_uncer': 0.1017525937529222}
# rxn00120 {'dG_mean': -25.8255546094569, 'dG_uncer': 0.102070101081552}
# rxn00121 {'dG_mean': -22.00354723789769, 'dG_uncer': 1.6177805752184709}
# rxn00122 {'dG_mean': -12.834825019638204, 'dG_uncer': 1.6176865608531592}
# rxn00123 {'dG_mean': 3.2052806014696102, 'dG_uncer': 1.3055359934699722}
# rxn00124 {'dG_mean': -29.96489677151192, 'dG_uncer': 1.305528688215677}
# rxn00125 {'dG_mean': 45.81061554791265, 'dG_uncer': 2.9670398221327883}
# rxn00126 {'dG_mean': 75.12473551425916, 'dG_uncer': 3.0663144712456543}
# rxn00127 {'dG_mean': -34.110502173205134, 'dG_uncer': 0.7248503468784511}
# rxn00128 {'dG_mean': -40.17619552578466, 'dG_uncer': 3.1733695476761383}
# rxn00129 {'dG_mean': 43.36073023629093, 'dG_uncer': 3.303034999621806}
# rxn00130 {'dG_mean': -23.64091826407896, 'dG_uncer': 0.1045762377507601}
# rxn00131 {'dG_mean': -12.720666139724273, 'dG_uncer': 0.110354401601264}
# rxn00132 {'dG_mean': -12.417410007887838, 'dG_uncer': 0.1022898756454585}
# rxn00133 {'dG_mean': -36.81164012727197, 'dG_uncer': 0.1160446688606811}
# rxn00134 {'dG_mean': -14.342206162154524, 'dG_uncer': 0.102352361368536}
# rxn00135 {'dG_mean': -14.342206162154524, 'dG_uncer': 0.102352361368536}
# rxn00136 {'dG_mean': -37.199678933065, 'dG_uncer': 0.1160446688606811}
# rxn00137 {'dG_mean': 0.2576511624270665, 'dG_uncer': 0.896786224581303}
# rxn00138 {'dG_mean': 0.3182882371346807, 'dG_uncer': 2.1428538235380525}
# rxn00139 {'dG_mean': 19.86207589125169, 'dG_uncer': 0.1095431602423529}
# rxn00140 {'dG_mean': -41.86760684025859, 'dG_uncer': 0.1085720612476008}
# rxn00141 {'dG_mean': 34.76398755725391, 'dG_uncer': 0.1436477300376917}
# rxn00142 {'dG_mean': -23.63145374027296, 'dG_uncer': 0.1045762377507601}
# rxn00143 {'dG_mean': 1.9385967274097595, 'dG_uncer': 0.9809254925510184}
# rxn00144 {'dG_mean': 8.806987657094908, 'dG_uncer': 1.468180734714023}
# rxn00147 {'dG_mean': 3.441010488398959, 'dG_uncer': 0.1029680711575061}
# rxn00148 {'dG_mean': 27.498729285734697, 'dG_uncer': 0.1026263772594054}
# rxn00149 {'dG_mean': -13.233933653745863, 'dG_uncer': 0.8012031687359}
# rxn00150 {'dG_mean': -15.674556745593762, 'dG_uncer': 0.8012031687359}
# rxn00151 {'dG_mean': 19.419973198241067, 'dG_uncer': 0.1029330378007277}
# rxn00152 {'dG_mean': -157.97770799954208, 'dG_uncer': 0.2077213370314763}
# rxn00153 {'dG_mean': -54.25834545577702, 'dG_uncer': 0.1031819433977604}
# rxn00154 {'dG_mean': -33.07792161702437, 'dG_uncer': 0.1504705376138865}
# rxn00155 {'dG_mean': -35.51854470887216, 'dG_uncer': 0.1504705376138865}
# rxn00156 {'dG_mean': -167.8309689756864, 'dG_uncer': 0.20720402188504}
# rxn00157 {'dG_mean': 21.024166502419654, 'dG_uncer': 0.1136920154097347}
# rxn00158 {'dG_mean': -86.68250159141195, 'dG_uncer': 0.9257994764678344}
# rxn00159 {'dG_mean': 13.78820010396828, 'dG_uncer': 0.1479772230068939}
# rxn00160 {'dG_mean': 24.150060131547576, 'dG_uncer': 0.2052746843062028}
# rxn00161 {'dG_mean': 11.347577012120382, 'dG_uncer': 0.1479772230068939}
# rxn00162 {'dG_mean': -16.858102712652823, 'dG_uncer': 0.1479779172497816}
# rxn00163 {'dG_mean': 72.55464652911007, 'dG_uncer': 3.3001943053325613}
# rxn00164 {'dG_mean': 16.857440503149547, 'dG_uncer': 0.1479779172497816}
# rxn00165 {'dG_mean': -29.827195037029128, 'dG_uncer': 0.1061959630563144}
# rxn00166 {'dG_mean': -34.2842226487907, 'dG_uncer': 0.9371078477747552}
# rxn00168 {'dG_mean': -17.310396554292126, 'dG_uncer': 0.1521277599463529}
# rxn00170 {'dG_mean': -30.30534371520156, 'dG_uncer': 0.1030548393959195}
# rxn00171 {'dG_mean': -15.76752506273229, 'dG_uncer': 0.1096791007303174}
# rxn00172 {'dG_mean': 3.545727545159337, 'dG_uncer': 0.1024509670186723}
# rxn00173 {'dG_mean': 9.85326097614444, 'dG_uncer': 0.1037500922509735}
# rxn00174 {'dG_mean': -24.61128926334908, 'dG_uncer': 0.6960931542198214}
# rxn00175 {'dG_mean': -4.533028542334279, 'dG_uncer': 0.1025346550935799}
# rxn00176 {'dG_mean': -62.87811575700698, 'dG_uncer': 1.143303147545775}
# rxn00177 {'dG_mean': 4.542067157174188, 'dG_uncer': 0.7449622286587984}
# rxn00178 {'dG_mean': 26.311336509800384, 'dG_uncer': 0.1058736522587862}
# rxn00179 {'dG_mean': 12.82527254400472, 'dG_uncer': 0.8943137209698793}
# rxn00180 {'dG_mean': 12.82527254400472, 'dG_uncer': 0.8943137209698793}
# rxn00181 {'dG_mean': 11.61271127465102, 'dG_uncer': 1.0916770612656863}
# rxn00182 {'dG_mean': 38.5808841776209, 'dG_uncer': 0.1020318813208989}
# rxn00183 {'dG_mean': -22.18033082608457, 'dG_uncer': 0.1355948552253515}
# rxn00184 {'dG_mean': 36.140261085773005, 'dG_uncer': 0.1020318813208989}
# rxn00185 {'dG_mean': -96.17216318104114, 'dG_uncer': 0.1771020297562464}
# rxn00186 {'dG_mean': -31.428338173585445, 'dG_uncer': 1.6377434394779709}
# rxn00187 {'dG_mean': -15.148507219314638, 'dG_uncer': 0.1055695959588168}
# rxn00188 {'dG_mean': 11.014643569565848, 'dG_uncer': 1.3684889351975569}
# rxn00189 {'dG_mean': -11.611108950727669, 'dG_uncer': 0.1058318268282758}
# rxn00190 {'dG_mean': -11.292820713592846, 'dG_uncer': 2.143027859840919}
# rxn00191 {'dG_mean': 0.6717178860797048, 'dG_uncer': 0.1031878733693378}
# rxn00192 {'dG_mean': -7.1998768689722255, 'dG_uncer': 1.0741395062276848}
# rxn00193 {'dG_mean': 0.1792497300114952, 'dG_uncer': 0.1258386443866851}
# rxn00194 {'dG_mean': -36.61088053486387, 'dG_uncer': 0.1791307206222759}
# rxn00195 {'dG_mean': -6.663733691053404, 'dG_uncer': 0.1303658187313163}
# rxn00196 {'dG_mean': -25.855122982140585, 'dG_uncer': 0.1355948552253515}
# rxn00197 {'dG_mean': -29.214260302106624, 'dG_uncer': 0.1615234719308822}
# rxn00198 {'dG_mean': 6.002488877161909, 'dG_uncer': 0.1496783560657706}
# rxn00199 {'dG_mean': -15.268503784713689, 'dG_uncer': 0.7804174349142966}
# rxn00200 {'dG_mean': -12.82588450967961, 'dG_uncer': 0.1058318268282758}
# rxn00201 {'dG_mean': 40.95234515837774, 'dG_uncer': 0.1507172172950333}
# rxn00202 {'dG_mean': -41.57290029850874, 'dG_uncer': 0.7501734325650707}
# rxn00203 {'dG_mean': -30.50076341455363, 'dG_uncer': 0.1720170537160453}
# rxn00204 {'dG_mean': -164.60257219575047, 'dG_uncer': 0.2872489329556009}
# rxn00205 {'dG_mean': -309.84382132527804, 'dG_uncer': 0.1528601991092683}
# rxn00206 {'dG_mean': -34.941423571895086, 'dG_uncer': 4.109957586582801}
# rxn00207 {'dG_mean': 176.9400558477526, 'dG_uncer': 0.2284716097814078}
# rxn00208 {'dG_mean': -97.47869641469195, 'dG_uncer': 0.2047496232864179}
# rxn00209 {'dG_mean': -104.2970653940002, 'dG_uncer': 0.1908916852591234}
# rxn00210 {'dG_mean': -96.3514129110526, 'dG_uncer': 0.1919386233659993}
# rxn00211 {'dG_mean': 7.81256470725566, 'dG_uncer': 0.7402766644592377}
# rxn00212 {'dG_mean': -33.19042313581667, 'dG_uncer': 0.1040779189531656}
# rxn00213 {'dG_mean': -0.1228546833755217, 'dG_uncer': 0.1028510880209889}
# rxn00214 {'dG_mean': 2.9409464842964823, 'dG_uncer': 0.1056206660054063}
# rxn00215 {'dG_mean': -34.65313681046767, 'dG_uncer': 1.2497665695633655}
# rxn00216 {'dG_mean': -14.358435635371391, 'dG_uncer': 0.102352361368536}
# rxn00217 {'dG_mean': -0.8531634694553816, 'dG_uncer': 0.1058313467915303}
# rxn00218 {'dG_mean': 12.166648344270923, 'dG_uncer': 0.9991657958295104}
# rxn00219 {'dG_mean': -89.98656152384194, 'dG_uncer': 1.2142422072189525}
# rxn00220 {'dG_mean': -12.401180534670914, 'dG_uncer': 0.1022898756454585}
# rxn00221 {'dG_mean': -18.783356849090453, 'dG_uncer': 0.104551228803959}
# rxn00222 {'dG_mean': -12.045550791775554, 'dG_uncer': 0.1064539307897154}
# rxn00223 {'dG_mean': 0.8797340678139562, 'dG_uncer': 0.1019540285336641}
# rxn00224 {'dG_mean': 80.92919408761789, 'dG_uncer': 0.1435256569389332}
# rxn00225 {'dG_mean': 13.398988521303636, 'dG_uncer': 0.1033789852828447}
# rxn00226 {'dG_mean': 58.34508721467279, 'dG_uncer': 1.1432763032348794}
# rxn00227 {'dG_mean': -40.15860469134596, 'dG_uncer': 0.1038525028732769}
# rxn00228 {'dG_mean': -163.1687817002475, 'dG_uncer': 1.1208662445771989}
# rxn00229 {'dG_mean': -500.0546506372757, 'dG_uncer': 0.183768598150746}
# rxn00230 {'dG_mean': 24.179641981503693, 'dG_uncer': 0.1039405303313898}
# rxn00231 {'dG_mean': -40.10055004460324, 'dG_uncer': 1.800419827235083}
# rxn00232 {'dG_mean': -93.18345947220854, 'dG_uncer': 1.1434249407438388}
# rxn00233 {'dG_mean': -35.76934917035408, 'dG_uncer': 0.6588413795766181}
# rxn00234 {'dG_mean': 2.0707380529669592, 'dG_uncer': 0.1092877887477398}
# rxn00235 {'dG_mean': -31.43386909778744, 'dG_uncer': 1.2897445310495057}
# rxn00236 {'dG_mean': -24.208130645558185, 'dG_uncer': 0.1021136723263912}
# rxn00237 {'dG_mean': 0.0359616777719793, 'dG_uncer': 0.1016106817481443}
# rxn00239 {'dG_mean': -2.5514855244841783, 'dG_uncer': 0.1017525937529222}
# rxn00241 {'dG_mean': -26.79557784781429, 'dG_uncer': 0.102070101081552}
# rxn00242 {'dG_mean': -19.2317861982564, 'dG_uncer': 1.1338815621018377}
# rxn00243 {'dG_mean': -31.73174098208763, 'dG_uncer': 0.1462153816428724}
# rxn00244 {'dG_mean': -50.39184320779037, 'dG_uncer': 0.1532882610372863}
# rxn00245 {'dG_mean': -53.93379560848217, 'dG_uncer': 0.6473756309521185}
# rxn00247 {'dG_mean': 10.640626573081876, 'dG_uncer': 0.1478823158047897}
# rxn00248 {'dG_mean': 30.646302816621088, 'dG_uncer': 0.1021518927730387}
# rxn00249 {'dG_mean': 28.20567972477319, 'dG_uncer': 0.1021518927730387}
# rxn00250 {'dG_mean': -4.991596499133152, 'dG_uncer': 0.1041990816455919}
# rxn00251 {'dG_mean': 37.4002427431242, 'dG_uncer': 0.1477327367821839}
# rxn00252 {'dG_mean': 21.42128003328193, 'dG_uncer': 0.1478479455021031}
# rxn00253 {'dG_mean': -40.358671901422014, 'dG_uncer': 0.5274650555409024}
# rxn00254 {'dG_mean': -20.28721961635216, 'dG_uncer': 0.7330674791290057}
# rxn00255 {'dG_mean': 11.895071177704978, 'dG_uncer': 0.7832955068247389}
# rxn00256 {'dG_mean': 34.84596922579213, 'dG_uncer': 0.102704740356708}
# rxn00257 {'dG_mean': 8.086353055749896, 'dG_uncer': 0.1026908323749772}
# rxn00258 {'dG_mean': -7.753186550696114, 'dG_uncer': 0.6883547717567711}
# rxn00259 {'dG_mean': 7.207411000439635, 'dG_uncer': 0.8806555094752399}
# rxn00260 {'dG_mean': 3.013234063682944, 'dG_uncer': 0.1033233643730427}
# rxn00261 {'dG_mean': 3.013234063682944, 'dG_uncer': 0.1033233643730427}
# rxn00262 {'dG_mean': -93.15892911735818, 'dG_uncer': 0.1778183523072962}
# rxn00263 {'dG_mean': -99.88513193443328, 'dG_uncer': 0.6861531315966445}
# rxn00264 {'dG_mean': -104.10674454204091, 'dG_uncer': 0.1771704330431885}
# rxn00265 {'dG_mean': 4.540625510590587, 'dG_uncer': 0.1029031483091282}
# rxn00266 {'dG_mean': -0.0006622095032753, 'dG_uncer': 0.1016106817481443}
# rxn00268 {'dG_mean': 50.509061794535214, 'dG_uncer': 0.1136095962151006}
# rxn00269 {'dG_mean': -84.24398556412682, 'dG_uncer': 0.1834605926888759}
# rxn00270 {'dG_mean': 50.85113470895034, 'dG_uncer': 3.130136554462986}
# rxn00271 {'dG_mean': 14.55598098455927, 'dG_uncer': 1.556408424169114}
# rxn00272 {'dG_mean': -11.256459730834608, 'dG_uncer': 0.1145939628006248}
# rxn00273 {'dG_mean': -11.256459730834608, 'dG_uncer': 0.1145939628006248}
# rxn00274 {'dG_mean': 24.772613673539723, 'dG_uncer': 0.9397993275855004}
# rxn00275 {'dG_mean': 11.928177616914311, 'dG_uncer': 0.1135330252960029}
# rxn00276 {'dG_mean': 8.914943553231353, 'dG_uncer': 0.1141681552861562}
# rxn00277 {'dG_mean': 8.914943553231353, 'dG_uncer': 0.1141681552861562}
# rxn00278 {'dG_mean': 39.25260206370058, 'dG_uncer': 0.1032171214608951}
# rxn00279 {'dG_mean': -14.516586535049557, 'dG_uncer': 0.1495611087458447}
# rxn00280 {'dG_mean': 34.98656000030442, 'dG_uncer': 0.1436801134192741}
# rxn00281 {'dG_mean': 34.98656000030442, 'dG_uncer': 0.1436801134192741}
# rxn00282 {'dG_mean': -2.341516177603268, 'dG_uncer': 0.1046547643707248}
# rxn00283 {'dG_mean': 0.0157670107163596, 'dG_uncer': 0.1074221112413671}
# rxn00284 {'dG_mean': 70.06079527551793, 'dG_uncer': 0.122330973059748}
# rxn00285 {'dG_mean': 0.4241783663629235, 'dG_uncer': 0.1028525553481028}
# rxn00286 {'dG_mean': -3.2704217562809106, 'dG_uncer': 0.1352596165175326}
# rxn00287 {'dG_mean': -27.183794536405145, 'dG_uncer': 0.1033069574740483}
# rxn00288 {'dG_mean': 51.52885175368198, 'dG_uncer': 0.1588545626388822}
# rxn00289 {'dG_mean': 20.748198619424382, 'dG_uncer': 1.0351143612442928}
# rxn00290 {'dG_mean': 10.823649315142006, 'dG_uncer': 0.1040323838080908}
# rxn00291 {'dG_mean': -2.308329795738018, 'dG_uncer': 1.637685850892677}
# rxn00292 {'dG_mean': -22.735597440956155, 'dG_uncer': 0.1859655022920507}
# rxn00293 {'dG_mean': -0.101393295706373, 'dG_uncer': 0.1028510880209889}
# rxn00295 {'dG_mean': 0.9289846669400248, 'dG_uncer': 1.1820364258207412}
# rxn00297 {'dG_mean': -2.3780729713507327, 'dG_uncer': 1.0763281117697472}
# rxn00298 {'dG_mean': 7.634756416102277, 'dG_uncer': 0.6915041768665051}
# rxn00299 {'dG_mean': -167.8875034961901, 'dG_uncer': 2.3615845818443644}
# rxn00300 {'dG_mean': -18.281636788946912, 'dG_uncer': 1.5464907232674323}
# rxn00301 {'dG_mean': -35.02474578353019, 'dG_uncer': 0.1032394126363634}
# rxn00302 {'dG_mean': 8.319535616929343, 'dG_uncer': 0.1436772863493903}
# rxn00303 {'dG_mean': -20.820031629571247, 'dG_uncer': 1.1337947082355135}
# rxn00304 {'dG_mean': 27.462767607962704, 'dG_uncer': 0.1026263772594054}
# rxn00305 {'dG_mean': 10.60466489530991, 'dG_uncer': 0.1478823158047897}
# rxn00306 {'dG_mean': 0.3882166885908304, 'dG_uncer': 0.1028525553481028}
# rxn00307 {'dG_mean': 6.80642873228777, 'dG_uncer': 0.1072287867113477}
# rxn00308 {'dG_mean': 1.420633572932516, 'dG_uncer': 0.1783077547696541}
# rxn00309 {'dG_mean': 45.89662277137498, 'dG_uncer': 0.1139221435888447}
# rxn00310 {'dG_mean': -93.2626440978683, 'dG_uncer': 0.1909026361443834}
# rxn00311 {'dG_mean': -235.1524275526702, 'dG_uncer': 1.5979805801463791}
# rxn00312 {'dG_mean': -455.9268666072995, 'dG_uncer': 0.2405630605969308}
# rxn00313 {'dG_mean': -26.239732324266072, 'dG_uncer': 0.2409404828669701}
# rxn00314 {'dG_mean': 48.96202598466397, 'dG_uncer': 1.2167487598911209}
# rxn00315 {'dG_mean': 6.644020707674343, 'dG_uncer': 0.1149544859335073}
# rxn00316 {'dG_mean': -4.211722370693877, 'dG_uncer': 1.0479409306939311}
# rxn00317 {'dG_mean': 7.315738593754048, 'dG_uncer': 0.1135471432381564}
# rxn00318 {'dG_mean': -26.093621344507667, 'dG_uncer': 1.0479535706231786}
# rxn00319 {'dG_mean': -24.945900216016756, 'dG_uncer': 0.1754008364808223}
# rxn00320 {'dG_mean': -0.7748435467468227, 'dG_uncer': 0.1243359520411691}
# rxn00321 {'dG_mean': -4.608405892974247, 'dG_uncer': 0.124394707384213}
# rxn00322 {'dG_mean': -28.246204558341304, 'dG_uncer': 0.2304653416321158}
# rxn00323 {'dG_mean': 1.383389094941478, 'dG_uncer': 1.1188378357520383}
# rxn00324 {'dG_mean': 42.51467835244456, 'dG_uncer': 0.1058288458668055}
# rxn00325 {'dG_mean': -158.81623959761572, 'dG_uncer': 0.2097588498932606}
# rxn00326 {'dG_mean': -7.4094687820769565, 'dG_uncer': 0.1113036367551855}
# rxn00327 {'dG_mean': -25.57232812666368, 'dG_uncer': 0.1959979981060352}
# rxn00328 {'dG_mean': 18.47489588888953, 'dG_uncer': 0.1143590378124019}
# rxn00330 {'dG_mean': 34.62299556298595, 'dG_uncer': 0.1203095887709746}
# rxn00331 {'dG_mean': 10.709622782861828, 'dG_uncer': 0.1313599595472085}
# rxn00332 {'dG_mean': 26.751080023574104, 'dG_uncer': 1.088321462112392}
# rxn00333 {'dG_mean': -89.79774591436956, 'dG_uncer': 0.179237328293004}
# rxn00334 {'dG_mean': -43.02661359728771, 'dG_uncer': 1.6711930490246167}
# rxn00335 {'dG_mean': -8.45783229052384, 'dG_uncer': 0.530467964958102}
# rxn00336 {'dG_mean': 8.39839729838792, 'dG_uncer': 0.1115672550322933}
# rxn00337 {'dG_mean': 18.13733765811932, 'dG_uncer': 0.1431714167557806}
# rxn00338 {'dG_mean': -77.71777678508835, 'dG_uncer': 1.8656210698698832}
# rxn00339 {'dG_mean': -10.314105920599047, 'dG_uncer': 0.1581440833334216}
# rxn00340 {'dG_mean': -18.392862008092493, 'dG_uncer': 0.158755544203875}
# rxn00341 {'dG_mean': -32.32238528836267, 'dG_uncer': 0.1980402566991959}
# rxn00342 {'dG_mean': -16.445510249443252, 'dG_uncer': 0.1580155565812636}
# rxn00343 {'dG_mean': -1.6367874346480846, 'dG_uncer': 1.3586939341005384}
# rxn00344 {'dG_mean': 14.119409427929767, 'dG_uncer': 1.1559860664135648}
# rxn00345 {'dG_mean': -44.42475314313136, 'dG_uncer': 1.1559708980522985}
# rxn00346 {'dG_mean': -22.488101217981068, 'dG_uncer': 0.2283650673145408}
# rxn00347 {'dG_mean': 14.359730550635504, 'dG_uncer': 0.1029434574931988}
# rxn00348 {'dG_mean': 6.726202817075119, 'dG_uncer': 0.6707008618747331}
# rxn00349 {'dG_mean': 6.726202817075119, 'dG_uncer': 0.6707008618747331}
# rxn00350 {'dG_mean': 22.081218989021465, 'dG_uncer': 1.8655379317227991}
# rxn00351 {'dG_mean': -44.609272774375455, 'dG_uncer': 1.1510643589882712}
# rxn00352 {'dG_mean': -28.54934528099696, 'dG_uncer': 1.5022251157609732}
# rxn00353 {'dG_mean': -28.54934528099696, 'dG_uncer': 1.5022251157609732}
# rxn00354 {'dG_mean': 3.764966957173641, 'dG_uncer': 0.7407221319209862}
# rxn00355 {'dG_mean': -10.130279152501004, 'dG_uncer': 0.9264615855572792}
# rxn00356 {'dG_mean': -10.63693104505613, 'dG_uncer': 0.1197601782958979}
# rxn00357 {'dG_mean': -3.085935563578289, 'dG_uncer': 1.486107576170873}
# rxn00358 {'dG_mean': 17.775739089316573, 'dG_uncer': 1.2891997084974451}
# rxn00359 {'dG_mean': -82.20882447585572, 'dG_uncer': 0.1105872097129991}
# rxn00360 {'dG_mean': 0.3534227618060868, 'dG_uncer': 0.896786224581303}
# rxn00361 {'dG_mean': -27.113038931848426, 'dG_uncer': 0.8967537440727514}
# rxn00362 {'dG_mean': 21.556889046945884, 'dG_uncer': 2.1279309969365894}
# rxn00363 {'dG_mean': -12.468169496553172, 'dG_uncer': 0.1022898756454585}
# rxn00364 {'dG_mean': -2.568508646627606, 'dG_uncer': 0.1017525937529222}
# rxn00365 {'dG_mean': -14.29144667348919, 'dG_uncer': 0.102352361368536}
# rxn00366 {'dG_mean': -24.1911075234147, 'dG_uncer': 0.1021136723263912}
# rxn00367 {'dG_mean': -34.956675727581114, 'dG_uncer': 0.1032394126363634}
# rxn00368 {'dG_mean': -13.357385112903785, 'dG_uncer': 0.102352361368536}
# rxn00369 {'dG_mean': -14.32740835126117, 'dG_uncer': 0.102352361368536}
# rxn00370 {'dG_mean': 69.22424190838106, 'dG_uncer': 1.0200347259589753}
# rxn00371 {'dG_mean': -12.05375511460472, 'dG_uncer': 0.1519716249425109}
# rxn00372 {'dG_mean': -90.94476322187263, 'dG_uncer': 1.0205620520898058}
# rxn00373 {'dG_mean': -17.795769722483733, 'dG_uncer': 0.1819795288807914}
# rxn00374 {'dG_mean': -59.24319655085196, 'dG_uncer': 2.740663981438641}
# rxn00375 {'dG_mean': -34.67937653094742, 'dG_uncer': 1.765875988111549}
# rxn00376 {'dG_mean': -55.99004028961775, 'dG_uncer': 1.4353698819350018}
# rxn00377 {'dG_mean': -81.69157968859191, 'dG_uncer': 1.2926797737198543}
# rxn00379 {'dG_mean': 47.4662238176989, 'dG_uncer': 0.109226089650311}
# rxn00380 {'dG_mean': 58.24687727789893, 'dG_uncer': 0.1095459726697499}
# rxn00381 {'dG_mean': -82.30459607523471, 'dG_uncer': 0.1105872097129991}
# rxn00382 {'dG_mean': -154.92719993191625, 'dG_uncer': 2.2844903543707207}
# rxn00383 {'dG_mean': -171.13119088202464, 'dG_uncer': 0.2176669710342286}
# rxn00384 {'dG_mean': -121.5805891442717, 'dG_uncer': 2.2458177510086066}
# rxn00385 {'dG_mean': -32.51113816307881, 'dG_uncer': 2.594125043951262}
# rxn00386 {'dG_mean': -39.48902194256519, 'dG_uncer': 3.189679695643409}
# rxn00387 {'dG_mean': -35.20642791935586, 'dG_uncer': 2.4630649812418306}
# rxn00391 {'dG_mean': -21.615303714138392, 'dG_uncer': 1.6170490889829168}
# rxn00392 {'dG_mean': -5.144312455903986, 'dG_uncer': 1.6170451306535265}
# rxn00393 {'dG_mean': 2.8319468650478825, 'dG_uncer': 1.6171734693715738}
# rxn00394 {'dG_mean': -28.691349495740155, 'dG_uncer': 0.2388410149807968}
# rxn00395 {'dG_mean': -34.791375728505336, 'dG_uncer': 0.1542355239965621}
# rxn00396 {'dG_mean': 5.32685804928218, 'dG_uncer': 0.1030939940533578}
# rxn00397 {'dG_mean': 5.32685804928218, 'dG_uncer': 0.1030939940533578}
# rxn00398 {'dG_mean': 5.32685804928218, 'dG_uncer': 0.1030939940533578}
# rxn00399 {'dG_mean': 5.32685804928218, 'dG_uncer': 0.1030939940533578}
# rxn00400 {'dG_mean': -286.2389364381033, 'dG_uncer': 2.5765627431082985}
# rxn00401 {'dG_mean': -455.9157285221385, 'dG_uncer': 0.2405630605969308}
# rxn00402 {'dG_mean': 32.69887799301611, 'dG_uncer': 0.1436495730515709}
# rxn00403 {'dG_mean': 53.39009691728731, 'dG_uncer': 0.9564387224373302}
# rxn00404 {'dG_mean': -0.2956784207390548, 'dG_uncer': 0.143485639849537}
# rxn00405 {'dG_mean': -28.23719090731853, 'dG_uncer': 0.2304653416321158}
# rxn00406 {'dG_mean': -0.7748435467468227, 'dG_uncer': 0.1243359520411691}
# rxn00407 {'dG_mean': -18.129092385572108, 'dG_uncer': 0.1086256639011242}
# rxn00408 {'dG_mean': -26.74453091400869, 'dG_uncer': 0.102070101081552}
# rxn00409 {'dG_mean': -0.0150852560336716, 'dG_uncer': 0.1016106817481443}
# rxn00410 {'dG_mean': -8.6305237844702, 'dG_uncer': 0.109055580193778}
# rxn00411 {'dG_mean': 27.5138145417684, 'dG_uncer': 0.1026263772594054}
# rxn00412 {'dG_mean': -20.24163273519781, 'dG_uncer': 0.1136562741434572}
# rxn00413 {'dG_mean': 6.917171356752817, 'dG_uncer': 0.1072287867113477}
# rxn00414 {'dG_mean': -6.794948789047936, 'dG_uncer': 0.136468291597552}
# rxn00415 {'dG_mean': 0.5430576728722372, 'dG_uncer': 0.1031878733693378}
# rxn00416 {'dG_mean': -30.00397095882033, 'dG_uncer': 0.1608315653087773}
# rxn00417 {'dG_mean': 0.1792497300114952, 'dG_uncer': 0.1258386443866851}
# rxn00418 {'dG_mean': 0.1792497300114952, 'dG_uncer': 0.1258386443866851}
# rxn00419 {'dG_mean': 46.021122359573326, 'dG_uncer': 0.1047357892635696}
# rxn00420 {'dG_mean': -10.257849933722412, 'dG_uncer': 0.1020605263758329}
# rxn00421 {'dG_mean': -5.721112776119867, 'dG_uncer': 0.1022423852265105}
# rxn00422 {'dG_mean': 6.768520295872719, 'dG_uncer': 0.1047363233167112}
# rxn00423 {'dG_mean': -6.718354329838007, 'dG_uncer': 0.1435922431965704}
# rxn00424 {'dG_mean': -4.4879394349618735, 'dG_uncer': 0.115270368409683}
# rxn00425 {'dG_mean': 4.457027611761575, 'dG_uncer': 0.9372534841883158}
# rxn00426 {'dG_mean': -30.42974745251314, 'dG_uncer': 2.313210285383301}
# rxn00427 {'dG_mean': -293.98533545072297, 'dG_uncer': 0.1896345362440493}
# rxn00428 {'dG_mean': 98.573931708879, 'dG_uncer': 2.065877930184072}
# rxn00429 {'dG_mean': -40.81851291237186, 'dG_uncer': 0.1214443565844494}
# rxn00430 {'dG_mean': 35.48459752417806, 'dG_uncer': 0.1525904918525396}
# rxn00431 {'dG_mean': 35.48459752417806, 'dG_uncer': 0.1525904918525396}
# rxn00432 {'dG_mean': -99.26844983448396, 'dG_uncer': 0.2087647983177153}
# rxn00433 {'dG_mean': -90.05602905638972, 'dG_uncer': 1.1175553768611126}
# rxn00434 {'dG_mean': -66.9613829521227, 'dG_uncer': 1.235205678894688}
# rxn00435 {'dG_mean': -76.30311043654993, 'dG_uncer': 0.1782520163932983}
# rxn00436 {'dG_mean': -25.47706539080184, 'dG_uncer': 0.1021136723263912}
# rxn00437 {'dG_mean': 1.4481294735614938, 'dG_uncer': 0.1016106817481443}
# rxn00438 {'dG_mean': -1.2825507792405233, 'dG_uncer': 0.1017525937529222}
# rxn00439 {'dG_mean': -28.207745643603857, 'dG_uncer': 0.102070101081552}
# rxn00440 {'dG_mean': -13.703417955956866, 'dG_uncer': 0.4526222871374846}
# rxn00441 {'dG_mean': -46.74201706894695, 'dG_uncer': 1.8082774709659408}
# rxn00442 {'dG_mean': -46.74201706894695, 'dG_uncer': 1.8082774709659408}
# rxn00444 {'dG_mean': -258.6924167166036, 'dG_uncer': 3.146013945472104}
# rxn00445 {'dG_mean': -103.1544704752639, 'dG_uncer': 2.2471189246502425}
# rxn00447 {'dG_mean': -103.1544704752639, 'dG_uncer': 2.2471189246502425}
# rxn00448 {'dG_mean': -533.1856431861697, 'dG_uncer': 2.2074804150719896}
# rxn00449 {'dG_mean': -0.0093644256941729, 'dG_uncer': 0.1016106817481443}
# rxn00450 {'dG_mean': -107.42182569682524, 'dG_uncer': 0.7187991461483054}
# rxn00451 {'dG_mean': 38.176495395835886, 'dG_uncer': 2.512514736446325}
# rxn00452 {'dG_mean': -6.895034308418261, 'dG_uncer': 3.068748132255384}
# rxn00453 {'dG_mean': -97.07575178510376, 'dG_uncer': 1.6625650774959464}
# rxn00454 {'dG_mean': -23.17784013269842, 'dG_uncer': 0.7059500077722389}
# rxn00455 {'dG_mean': -14.59034137144826, 'dG_uncer': 1.5673843310944848}
# rxn00456 {'dG_mean': 24.78791830425714, 'dG_uncer': 1.517184160321246}
# rxn00457 {'dG_mean': -10.231198638641343, 'dG_uncer': 0.7019452250286916}
# rxn00458 {'dG_mean': -40.79512444149475, 'dG_uncer': 0.8833315094079508}
# rxn00459 {'dG_mean': -4.179037283281929, 'dG_uncer': 0.1021569822513955}
# rxn00460 {'dG_mean': 28.432790846320074, 'dG_uncer': 0.1026263772594054}
# rxn00461 {'dG_mean': -25.68813037114556, 'dG_uncer': 1.55303776492162}
# rxn00462 {'dG_mean': 15.232223925841126, 'dG_uncer': 0.1436772086179744}
# rxn00463 {'dG_mean': -33.31327781919231, 'dG_uncer': 0.1032394126363634}
# rxn00464 {'dG_mean': -60.96992872669699, 'dG_uncer': 4.37219718761712}
# rxn00465 {'dG_mean': -24.535399674919887, 'dG_uncer': 0.1980631753093359}
# rxn00466 {'dG_mean': 42.319501070519976, 'dG_uncer': 1.1600911831112248}
# rxn00467 {'dG_mean': 18.120094290254883, 'dG_uncer': 0.1978352677517296}
# rxn00468 {'dG_mean': -57.9157624868073, 'dG_uncer': 1.8167334095498449}
# rxn00469 {'dG_mean': -20.05138155998172, 'dG_uncer': 1.075059170872002}
# rxn00470 {'dG_mean': -28.2462376551791, 'dG_uncer': 0.2304653416321158}
# rxn00471 {'dG_mean': -24.944462646801867, 'dG_uncer': 0.1754008364808223}
# rxn00472 {'dG_mean': -0.7748435467468227, 'dG_uncer': 0.1243359520411691}
# rxn00473 {'dG_mean': 21.102071807014227, 'dG_uncer': 0.104063162288306}
# rxn00474 {'dG_mean': -50.92926684404336, 'dG_uncer': 0.1084563955363383}
# rxn00475 {'dG_mean': -7.837511509687644, 'dG_uncer': 0.1895325390329965}
# rxn00476 {'dG_mean': -10.27813460153554, 'dG_uncer': 0.1895325390329965}
# rxn00477 {'dG_mean': -142.59055886834972, 'dG_uncer': 0.2384881164225265}
# rxn00478 {'dG_mean': -369.4733912508325, 'dG_uncer': 2.21165041531642}
# rxn00479 {'dG_mean': -487.3567445703485, 'dG_uncer': 1.346994706802655}
# rxn00480 {'dG_mean': -387.0814390808428, 'dG_uncer': 1.524309264295723}
# rxn00481 {'dG_mean': -15.11123630393115, 'dG_uncer': 1.3327159583797326}
# rxn00482 {'dG_mean': 11.82788540092993, 'dG_uncer': 3.259497236243189}
# rxn00483 {'dG_mean': -46.41839568730858, 'dG_uncer': 0.1893083583617307}
# rxn00484 {'dG_mean': -48.70272740367852, 'dG_uncer': 1.1052887694179936}
# rxn00485 {'dG_mean': -52.39140088004183, 'dG_uncer': 0.926696424076395}
# rxn00486 {'dG_mean': 304.95630899945087, 'dG_uncer': 2.1780778876794}
# rxn00487 {'dG_mean': 38.02385282894883, 'dG_uncer': 0.1246888643410922}
# rxn00488 {'dG_mean': -96.72919452971324, 'dG_uncer': 0.1910551427689632}
# rxn00489 {'dG_mean': -441.4955241703115, 'dG_uncer': 1.3458071626122432}
# rxn00490 {'dG_mean': 22.099536753821525, 'dG_uncer': 3.691668436437887}
# rxn00491 {'dG_mean': -1.228749234751806, 'dG_uncer': 0.1256367858844542}
# rxn00492 {'dG_mean': -22.376448916260287, 'dG_uncer': 1.3094331201266924}
# rxn00493 {'dG_mean': -0.5570313486720995, 'dG_uncer': 0.1243443211782406}
# rxn00494 {'dG_mean': 3.5702654123550435, 'dG_uncer': 0.1257478431756795}
# rxn00495 {'dG_mean': -3.3371458453034397, 'dG_uncer': 0.1034090978029984}
# rxn00496 {'dG_mean': -3.3371458453034397, 'dG_uncer': 0.1034090978029984}
# rxn00497 {'dG_mean': -48.70389307908317, 'dG_uncer': 1.1052887694179936}
# rxn00498 {'dG_mean': -111.20041744552358, 'dG_uncer': 5.519438361988666}
# rxn00499 {'dG_mean': 27.551595028513333, 'dG_uncer': 0.1028499571101412}
# rxn00500 {'dG_mean': 24.47463863820971, 'dG_uncer': 0.124358824504412}
# rxn00501 {'dG_mean': -21.152611146662466, 'dG_uncer': 0.2063860289019868}
# rxn00502 {'dG_mean': -23.59323423851025, 'dG_uncer': 0.2063860289019868}
# rxn00503 {'dG_mean': 5.169688483342966, 'dG_uncer': 0.240043115005233}
# rxn00504 {'dG_mean': 2.729065391495069, 'dG_uncer': 0.240043115005233}
# rxn00505 {'dG_mean': 8.443111969009806, 'dG_uncer': 0.1496783560657706}
# rxn00506 {'dG_mean': -46.07286877793385, 'dG_uncer': 0.1108179582727483}
# rxn00507 {'dG_mean': -48.51349186978175, 'dG_uncer': 0.1108179582727483}
# rxn00508 {'dG_mean': -23.456668332110382, 'dG_uncer': 0.1355948552253515}
# rxn00509 {'dG_mean': -25.89729142395828, 'dG_uncer': 0.1355948552253515}
# rxn00510 {'dG_mean': 38.31961346840478, 'dG_uncer': 0.1435160431692211}
# rxn00511 {'dG_mean': 35.87899037655677, 'dG_uncer': 0.1435160431692211}
# rxn00512 {'dG_mean': 44.95530144429246, 'dG_uncer': 0.1058288458668055}
# rxn00513 {'dG_mean': -26.75756263302685, 'dG_uncer': 0.102070101081552}
# rxn00514 {'dG_mean': -34.83145800231841, 'dG_uncer': 0.1032394126363634}
# rxn00515 {'dG_mean': -0.002053537015513, 'dG_uncer': 0.1016106817481443}
# rxn00516 {'dG_mean': -25.415304562319136, 'dG_uncer': 0.102070101081552}
# rxn00517 {'dG_mean': 27.50078282275024, 'dG_uncer': 0.1026263772594054}
# rxn00518 {'dG_mean': -14.35638209835588, 'dG_uncer': 0.102352361368536}
# rxn00519 {'dG_mean': 10.642680110097388, 'dG_uncer': 0.1478823158047897}
# rxn00520 {'dG_mean': 0.4262319033784365, 'dG_uncer': 0.1028525553481028}
# rxn00521 {'dG_mean': 29.454425854925745, 'dG_uncer': 0.2180657066645153}
# rxn00522 {'dG_mean': -96.10013303744051, 'dG_uncer': 0.1910274152368264}
# rxn00523 {'dG_mean': -248.8622571858169, 'dG_uncer': 1.8853531600765263}
# rxn00524 {'dG_mean': -268.33538238186725, 'dG_uncer': 1.7898058954778413}
# rxn00525 {'dG_mean': 82.62729810143595, 'dG_uncer': 3.691773870668598}
# rxn00526 {'dG_mean': 80.18667500958806, 'dG_uncer': 3.691773870668598}
# rxn00527 {'dG_mean': 0.0720301436006156, 'dG_uncer': 0.1243042304088074}
# rxn00528 {'dG_mean': -42.86725344591119, 'dG_uncer': 1.764927131020428}
# rxn00529 {'dG_mean': -48.69351671983264, 'dG_uncer': 1.1052887694179936}
# rxn00530 {'dG_mean': -3.342461521197208, 'dG_uncer': 0.1034090978029984}
# rxn00531 {'dG_mean': -19.381542918456788, 'dG_uncer': 1.5157574158956482}
# rxn00532 {'dG_mean': 1.0180550248388442, 'dG_uncer': 0.6977435971667219}
# rxn00533 {'dG_mean': 2.761590051563146, 'dG_uncer': 0.6885167475554108}
# rxn00534 {'dG_mean': -4.037758006532812, 'dG_uncer': 0.5728705418096631}
# rxn00535 {'dG_mean': -4.037758006532812, 'dG_uncer': 0.5728705418096631}
# rxn00536 {'dG_mean': 19.285112983081437, 'dG_uncer': 0.1022266884904451}
# rxn00537 {'dG_mean': -126.81655579694672, 'dG_uncer': 1.1951058810051036}
# rxn00538 {'dG_mean': -38.8546266516141, 'dG_uncer': 0.7872388465750353}
# rxn00539 {'dG_mean': -30.11667501006974, 'dG_uncer': 0.9143447564342856}
# rxn00540 {'dG_mean': -20.31326217147074, 'dG_uncer': 0.6898516298253784}
# rxn00541 {'dG_mean': 10.077774827170131, 'dG_uncer': 0.1278146837824476}
# rxn00542 {'dG_mean': 22.294953588825905, 'dG_uncer': 0.1197609125103239}
# rxn00543 {'dG_mean': 21.72573607492933, 'dG_uncer': 0.1022266884904451}
# rxn00544 {'dG_mean': -13.309635204464705, 'dG_uncer': 1.8165213114926384}
# rxn00545 {'dG_mean': -15.788426450984105, 'dG_uncer': 0.1039520063855967}
# rxn00546 {'dG_mean': 11.494015947797948, 'dG_uncer': 0.1098440805849716}
# rxn00547 {'dG_mean': -14.361359920094344, 'dG_uncer': 0.102352361368536}
# rxn00548 {'dG_mean': -47.81074024120784, 'dG_uncer': 0.1225754922886481}
# rxn00549 {'dG_mean': -10.971189719058202, 'dG_uncer': 0.1040744713730675}
# rxn00550 {'dG_mean': -26.719138774658237, 'dG_uncer': 0.9940489134273744}
# rxn00551 {'dG_mean': -5.007772990784076, 'dG_uncer': 0.104156321308467}
# rxn00552 {'dG_mean': 2.259416217296703, 'dG_uncer': 0.1243978181792361}
# rxn00553 {'dG_mean': 2.917590503856246, 'dG_uncer': 1.1488997918859918}
# rxn00554 {'dG_mean': -15.773341194950431, 'dG_uncer': 0.1039520063855967}
# rxn00555 {'dG_mean': -13.870525168024445, 'dG_uncer': 0.1278676218706829}
# rxn00556 {'dG_mean': -14.8543648903987, 'dG_uncer': 0.1039520063855967}
# rxn00557 {'dG_mean': -15.786372913968592, 'dG_uncer': 0.1039520063855967}
# rxn00558 {'dG_mean': 0.8768097830910051, 'dG_uncer': 0.1019540285336641}
# rxn00559 {'dG_mean': 0.2007862008786105, 'dG_uncer': 0.1071902103340947}
# rxn00560 {'dG_mean': 43.84553055512916, 'dG_uncer': 1.0235102386200434}
# rxn00561 {'dG_mean': -28.395671075001133, 'dG_uncer': 0.2590187826612103}
# rxn00562 {'dG_mean': 5.063097781021369, 'dG_uncer': 0.1173195143084365}
# rxn00563 {'dG_mean': -65.1426424739049, 'dG_uncer': 1.4095388504936783}
# rxn00564 {'dG_mean': 4.547804978674584, 'dG_uncer': 1.3292836401259838}
# rxn00565 {'dG_mean': -345.43130758997194, 'dG_uncer': 0.204581405802105}
# rxn00566 {'dG_mean': -2.939366032578306, 'dG_uncer': 0.1796164353901092}
# rxn00568 {'dG_mean': 402.1655031883122, 'dG_uncer': 0.1613884466895409}
# rxn00569 {'dG_mean': 394.8436339127691, 'dG_uncer': 0.1613884466895409}
# rxn00570 {'dG_mean': 317.1567249438335, 'dG_uncer': 1.98218854377265}
# rxn00571 {'dG_mean': 147.81138563567515, 'dG_uncer': 0.1774868928805615}
# rxn00572 {'dG_mean': 145.37076254382723, 'dG_uncer': 0.1774868928805615}
# rxn00573 {'dG_mean': 118.01669878252622, 'dG_uncer': 1.9511170626845349}
# rxn00574 {'dG_mean': 118.01669878252622, 'dG_uncer': 1.9511170626845349}
# rxn00575 {'dG_mean': -26.035041005690715, 'dG_uncer': 0.1075596392394376}
# rxn00577 {'dG_mean': -7.251684156600248, 'dG_uncer': 0.1047814806600822}
# rxn00578 {'dG_mean': -17.787899813443232, 'dG_uncer': 1.1489168392526576}
# rxn00579 {'dG_mean': -2.4720530596389665, 'dG_uncer': 0.1041386836593174}
# rxn00580 {'dG_mean': 2.887594484231812, 'dG_uncer': 1.2293985125014997}
# rxn00581 {'dG_mean': -13.611109598774604, 'dG_uncer': 0.1208278264929074}
# rxn00582 {'dG_mean': -16.963646474825353, 'dG_uncer': 0.1105316581527858}
# rxn00583 {'dG_mean': 119.87545284517536, 'dG_uncer': 3.270601966365543}
# rxn00584 {'dG_mean': 86.3697727278011, 'dG_uncer': 3.400830532207152}
# rxn00585 {'dG_mean': 113.60912549642823, 'dG_uncer': 3.656581261376795}
# rxn00586 {'dG_mean': -347.9197046014931, 'dG_uncer': 1.5172167335695206}
# rxn00587 {'dG_mean': -469.7532557097791, 'dG_uncer': 2.276455188941304}
# rxn00588 {'dG_mean': -505.39071986647264, 'dG_uncer': 2.27995547755626}
# rxn00589 {'dG_mean': -348.51332218993207, 'dG_uncer': 1.5276445676820938}
# rxn00590 {'dG_mean': -348.51332218993207, 'dG_uncer': 1.5276445676820938}
# rxn00591 {'dG_mean': -348.51332218993207, 'dG_uncer': 1.5276445676820938}
# rxn00592 {'dG_mean': -7.289786376499777, 'dG_uncer': 0.7992803409053691}
# rxn00593 {'dG_mean': -6.79730278800659, 'dG_uncer': 0.7664827543675525}
# rxn00594 {'dG_mean': -345.7355232710121, 'dG_uncer': 1.531270116415018}
# rxn00595 {'dG_mean': -343.2949001791642, 'dG_uncer': 1.531270116415018}
# rxn00596 {'dG_mean': -96.72332265783588, 'dG_uncer': 3.3347351268533547}
# rxn00597 {'dG_mean': -96.72332265783588, 'dG_uncer': 3.3347351268533547}
# rxn00598 {'dG_mean': -19.855159039649838, 'dG_uncer': 1.1943168400875634}
# rxn00599 {'dG_mean': -9.804267681432831, 'dG_uncer': 0.8453146984725246}
# rxn00600 {'dG_mean': -9.804267681432831, 'dG_uncer': 0.8453146984725246}
# rxn00601 {'dG_mean': -25.1850994042816, 'dG_uncer': 1.6387795846879918}
# rxn00602 {'dG_mean': -7.573100592156874, 'dG_uncer': 0.1244210785928418}
# rxn00603 {'dG_mean': 9.877333707807452, 'dG_uncer': 0.1050262535660231}
# rxn00604 {'dG_mean': -3.324542995906569, 'dG_uncer': 0.1058313467915303}
# rxn00605 {'dG_mean': -16.10661990288571, 'dG_uncer': 0.1179060986369129}
# rxn00606 {'dG_mean': -12.40047416244397, 'dG_uncer': 0.1200494648755587}
# rxn00607 {'dG_mean': -31.871069541241557, 'dG_uncer': 1.1245541672333306}
# rxn00608 {'dG_mean': -6.003515971478265, 'dG_uncer': 0.9377192322432408}
# rxn00609 {'dG_mean': -6.003515971478265, 'dG_uncer': 0.9377192322432408}
# rxn00610 {'dG_mean': -15.612985677583026, 'dG_uncer': 0.1174487848605909}
# rxn00611 {'dG_mean': 26.48376616115837, 'dG_uncer': 0.1047498436803443}
# rxn00612 {'dG_mean': 24.043143069310474, 'dG_uncer': 0.1047498436803443}
# rxn00613 {'dG_mean': 31.69237777054491, 'dG_uncer': 0.1062189329967637}
# rxn00614 {'dG_mean': -108.26928119750364, 'dG_uncer': 0.1785717815036391}
# rxn00615 {'dG_mean': -11.14663049245928, 'dG_uncer': 0.1175764051761028}
# rxn00616 {'dG_mean': 7.951822639322167, 'dG_uncer': 0.1468751297188606}
# rxn00617 {'dG_mean': -3.2118051429121124, 'dG_uncer': 0.1171584457592977}
# rxn00618 {'dG_mean': -17.26898023419308, 'dG_uncer': 1.0237343242827468}
# rxn00619 {'dG_mean': -8.59970660034233, 'dG_uncer': 0.9749742799357214}
# rxn00620 {'dG_mean': -31.4383553074436, 'dG_uncer': 0.3496143305439592}
# rxn00621 {'dG_mean': -3.5183204201374, 'dG_uncer': 0.3491184955574059}
# rxn00623 {'dG_mean': 125.66565959109948, 'dG_uncer': 0.1891616625785001}
# rxn00624 {'dG_mean': -106.62843589975526, 'dG_uncer': 1.7304139666241114}
# rxn00625 {'dG_mean': 323.5237967376913, 'dG_uncer': 2.0441386524330314}
# rxn00627 {'dG_mean': -11.070482313975845, 'dG_uncer': 0.1039520063855967}
# rxn00629 {'dG_mean': 11.468484515443492, 'dG_uncer': 0.1086809190528603}
# rxn00630 {'dG_mean': 9.027861423595482, 'dG_uncer': 0.1086809190528603}
# rxn00631 {'dG_mean': 21.168307466128425, 'dG_uncer': 0.1609418581883194}
# rxn00632 {'dG_mean': -31.46944255358824, 'dG_uncer': 0.9940489134273744}
# rxn00633 {'dG_mean': -13.921961018932762, 'dG_uncer': 0.1089385121088227}
# rxn00634 {'dG_mean': 13.068797549477438, 'dG_uncer': 0.1048283230279539}
# rxn00635 {'dG_mean': -14.359306383078774, 'dG_uncer': 0.102352361368536}
# rxn00636 {'dG_mean': -3.2604434882370583, 'dG_uncer': 0.1056020761020197}
# rxn00638 {'dG_mean': 1.896095813988154, 'dG_uncer': 1.0636713630892904}
# rxn00639 {'dG_mean': -30.53102585122264, 'dG_uncer': 0.1376402587094513}
# rxn00640 {'dG_mean': 6.322895205664565, 'dG_uncer': 0.136806026530582}
# rxn00641 {'dG_mean': -4.493719932307442, 'dG_uncer': 0.1364604424847675}
# rxn00642 {'dG_mean': -40.33658921384696, 'dG_uncer': 0.9916071333902348}
# rxn00643 {'dG_mean': 1.741680545401188, 'dG_uncer': 0.1436327243668131}
# rxn00644 {'dG_mean': -4.12619639691836, 'dG_uncer': 0.2490859265230055}
# rxn00645 {'dG_mean': -238.370562547612, 'dG_uncer': 1.7314646407915126}
# rxn00646 {'dG_mean': -36.52418532485535, 'dG_uncer': 1.885922774160481}
# rxn00647 {'dG_mean': -14.947565027066808, 'dG_uncer': 1.0416564755878468}
# rxn00649 {'dG_mean': -50.47481838981432, 'dG_uncer': 0.2073673537785219}
# rxn00650 {'dG_mean': 5.533006770124771, 'dG_uncer': 1.326576097403886}
# rxn00651 {'dG_mean': 206.22977812040108, 'dG_uncer': 2.1052666739347803}
# rxn00652 {'dG_mean': -13.202353378411322, 'dG_uncer': 1.080079659556474}
# rxn00653 {'dG_mean': -22.869977620802278, 'dG_uncer': 0.9829290383432924}
# rxn00654 {'dG_mean': -21.369228860169, 'dG_uncer': 1.2139470414953522}
# rxn00655 {'dG_mean': 43.05413312335921, 'dG_uncer': 1.4023622257103767}
# rxn00656 {'dG_mean': 3.953795787430465, 'dG_uncer': 0.1434096929935681}
# rxn00657 {'dG_mean': -3.2820779013507604, 'dG_uncer': 0.1445181200662366}
# rxn00658 {'dG_mean': -23.726261960070133, 'dG_uncer': 1.30331967877913}
# rxn00659 {'dG_mean': -21.49877924185276, 'dG_uncer': 1.7082685330486584}
# rxn00660 {'dG_mean': -5.260836928189519, 'dG_uncer': 1.7082424359696406}
# rxn00661 {'dG_mean': -21.425953496978902, 'dG_uncer': 1.7082685330486584}
# rxn00662 {'dG_mean': -26.7428150710833, 'dG_uncer': 1.219674931266031}
# rxn00663 {'dG_mean': -26.7428150710833, 'dG_uncer': 1.219674931266031}
# rxn00668 {'dG_mean': 44.36050524214119, 'dG_uncer': 1.885841389770976}
# rxn00669 {'dG_mean': 14.34965002062816, 'dG_uncer': 0.1437727425761308}
# rxn00670 {'dG_mean': 20.230330574557485, 'dG_uncer': 0.765559039515442}
# rxn00671 {'dG_mean': -38.402403772450526, 'dG_uncer': 0.933285032947281}
# rxn00672 {'dG_mean': -19.276109659375837, 'dG_uncer': 0.5634713136720041}
# rxn00673 {'dG_mean': 28.269184812152893, 'dG_uncer': 1.8885423977874427}
# rxn00674 {'dG_mean': 6.270893933134545, 'dG_uncer': 0.1434056032858842}
# rxn00675 {'dG_mean': -73.25144708225204, 'dG_uncer': 1.214153160243336}
# rxn00676 {'dG_mean': 10.92831741925042, 'dG_uncer': 0.766800633283091}
# rxn00677 {'dG_mean': 10.803922475468738, 'dG_uncer': 0.1440557804917089}
# rxn00678 {'dG_mean': -2.418006946723139, 'dG_uncer': 0.555417885713349}
# rxn00679 {'dG_mean': 43.66707491339866, 'dG_uncer': 0.794622171562895}
# rxn00680 {'dG_mean': 43.62234605293585, 'dG_uncer': 0.9258872747478568}
# rxn00681 {'dG_mean': 43.62234605293585, 'dG_uncer': 0.9258872747478568}
# rxn00682 {'dG_mean': -18.578819436576616, 'dG_uncer': 1.1223622309269203}
# rxn00684 {'dG_mean': 29.763269277091663, 'dG_uncer': 0.1086244130230917}
# rxn00685 {'dG_mean': 29.763269277091663, 'dG_uncer': 0.1086244130230917}
# rxn00686 {'dG_mean': 27.32264618524377, 'dG_uncer': 0.1086244130230917}
# rxn00687 {'dG_mean': 27.32264618524377, 'dG_uncer': 0.1086244130230917}
# rxn00688 {'dG_mean': -35.67297150784597, 'dG_uncer': 0.1584074821590059}
# rxn00689 {'dG_mean': -56.561193053350735, 'dG_uncer': 3.490986805781442}
# rxn00690 {'dG_mean': -5.5810228686488585, 'dG_uncer': 0.1215477818924994}
# rxn00691 {'dG_mean': -21.178593301393377, 'dG_uncer': 0.1219194577423236}
# rxn00692 {'dG_mean': 7.1247796249341775, 'dG_uncer': 0.1102989407703408}
# rxn00693 {'dG_mean': -37.95069155539864, 'dG_uncer': 1.4063490244410144}
# rxn00695 {'dG_mean': -1.5041393708923465, 'dG_uncer': 0.1028510880209889}
# rxn00696 {'dG_mean': -19.065996950498917, 'dG_uncer': 0.102352361368536}
# rxn00697 {'dG_mean': -33.33423288664335, 'dG_uncer': 0.1040779189531656}
# rxn00698 {'dG_mean': 6.737806057314955, 'dG_uncer': 0.1076950469867281}
# rxn00699 {'dG_mean': 2.678062223958861, 'dG_uncer': 0.1435520773425839}
# rxn00700 {'dG_mean': 2.1317689950251264, 'dG_uncer': 0.1436065482490207}
# rxn00701 {'dG_mean': -10.007424469125482, 'dG_uncer': 0.9264413859932862}
# rxn00702 {'dG_mean': -1.6017670715071404, 'dG_uncer': 0.1028510880209889}
# ...
# rxn40171 {'dG_mean': 1.307755303957208, 'dG_uncer': 1.9743022524137568}
# rxn40172 {'dG_mean': -104.48111881615613, 'dG_uncer': 1.9347708222191184}
# rxn40173 {'dG_mean': -373.59345980403407, 'dG_uncer': 2.547648709698771}
# rxn40174 {'dG_mean': -328.3853974612194, 'dG_uncer': 2.905592904758876}
# rxn40175 {'dG_mean': -117.60200864287776, 'dG_uncer': 5.1647984849740425}
# rxn40176 {'dG_mean': -9.536813728955408, 'dG_uncer': 1.0553271741067904}
# rxn40177 {'dG_mean': -482.7003487427711, 'dG_uncer': 2.5143259311819426}
# rxn40178 {'dG_mean': -381.4117538636384, 'dG_uncer': 1.3990833375985172}
# rxn40179 {'dG_mean': -440.44895887992254, 'dG_uncer': 1.812794054072064}
# rxn40180 {'dG_mean': -383.05459140840566, 'dG_uncer': 2.16054241206016}
# rxn40181 {'dG_mean': -280.9304904826095, 'dG_uncer': 3.6973697521444833}
# rxn40182 {'dG_mean': -386.9047793138736, 'dG_uncer': 1.9428029215286096}
# rxn40183 {'dG_mean': -383.0545912640859, 'dG_uncer': 2.16054241206016}
# rxn40184 {'dG_mean': -102.91065728604391, 'dG_uncer': 3.647192736756823}
# rxn40185 {'dG_mean': -389.51775486118186, 'dG_uncer': 2.479663719522265}
# rxn40186 {'dG_mean': -1142.477868504046, 'dG_uncer': 6.225442384313078}
# rxn40187 {'dG_mean': -390.6918568249164, 'dG_uncer': 1.6965769642763115}
# rxn40188 {'dG_mean': -256.3644370115674, 'dG_uncer': 3.9831623546773582}
# rxn40189 {'dG_mean': -54.59132431503377, 'dG_uncer': 1.4892768764737283}
# rxn40190 {'dG_mean': -840.106681298415, 'dG_uncer': 1.455684373310442}
# rxn40192 {'dG_mean': -395.4969895189048, 'dG_uncer': 1.6035708410507776}
# rxn40193 {'dG_mean': -1643.0725597807673, 'dG_uncer': 1.666564949682796}
# rxn40194 {'dG_mean': -1105.280274119668, 'dG_uncer': 3.203498001606655}
# rxn40195 {'dG_mean': -54.59132432226335, 'dG_uncer': 1.4892768764737283}
# rxn40196 {'dG_mean': -390.6918568489325, 'dG_uncer': 1.6965769642763115}
# rxn40197 {'dG_mean': -44.90091375926747, 'dG_uncer': 2.23120619254213}
# rxn40198 {'dG_mean': -266.95570635122493, 'dG_uncer': 3.9835686840216535}
# rxn40199 {'dG_mean': -258.0532876813234, 'dG_uncer': 3.552691146244236}
# rxn40204 {'dG_mean': 7.088351861872212, 'dG_uncer': 0.7870436482115566}
# rxn40205 {'dG_mean': 7.088635945352138, 'dG_uncer': 0.7870436482115566}
# rxn40207 {'dG_mean': -13.106809637462987, 'dG_uncer': 1.1434134066973063}
# rxn40208 {'dG_mean': -5.122625537583055, 'dG_uncer': 2.543744032410702}
# rxn40209 {'dG_mean': -6.194328896044468, 'dG_uncer': 2.6905903541526817}
# rxn40210 {'dG_mean': -14.17851299592428, 'dG_uncer': 0.7044659799770788}
# rxn40211 {'dG_mean': -44.84372593763996, 'dG_uncer': 1.209315512087104}
# rxn40215 {'dG_mean': -28.17318840705265, 'dG_uncer': 0.4826986048664422}
# rxn40217 {'dG_mean': -44.306621229422575, 'dG_uncer': 1.8092896176189623}
# rxn40218 {'dG_mean': -454.7482185747397, 'dG_uncer': 0.595721047025386}
# rxn40219 {'dG_mean': -741.0693917454192, 'dG_uncer': 1.7292589423783984}
# rxn40220 {'dG_mean': -453.1375761002524, 'dG_uncer': 2.148762153090725}
# rxn40221 {'dG_mean': 31.157704469735705, 'dG_uncer': 1.3926402185153424}
# rxn40222 {'dG_mean': 9.911934676129974, 'dG_uncer': 2.502613793524318}
# rxn40223 {'dG_mean': 14.19585612305211, 'dG_uncer': 0.1766570639948725}
# rxn40224 {'dG_mean': 7.062062174230967, 'dG_uncer': 0.990554856644536}
# rxn40225 {'dG_mean': 4.621439082383184, 'dG_uncer': 0.990554856644536}
# rxn40228 {'dG_mean': 21.168307466128425, 'dG_uncer': 0.1609418581883194}
# rxn40229 {'dG_mean': -21.50534116587036, 'dG_uncer': 3.2738976445983967}
# rxn40230 {'dG_mean': -38.01142614314313, 'dG_uncer': 1.5289030622244724}
# rxn40231 {'dG_mean': -17.572835523699453, 'dG_uncer': 1.0527310022141227}
# rxn40232 {'dG_mean': -43.897708187616864, 'dG_uncer': 1.214871097861953}
# rxn40233 {'dG_mean': -42.47105320194174, 'dG_uncer': 1.4749547334500124}
# rxn40234 {'dG_mean': -38.10111901460563, 'dG_uncer': 1.258157854712862}
# rxn40235 {'dG_mean': 11.755233031204211, 'dG_uncer': 0.1766570639948725}
# rxn40236 {'dG_mean': 25.122805249349284, 'dG_uncer': 13.734569904196382}
# rxn40237 {'dG_mean': -34.12084671661789, 'dG_uncer': 1.214326662985863}
# rxn40238 {'dG_mean': -8.066011170439594, 'dG_uncer': 1.1339333055083003}
# rxn40243 {'dG_mean': -430.0230242794023, 'dG_uncer': 0.9171347466881496}
# rxn40244 {'dG_mean': 6.739836973904247, 'dG_uncer': 3.364863608276433}
# rxn40245 {'dG_mean': 6.833814392967803, 'dG_uncer': 3.498261159958116}
# rxn40246 {'dG_mean': 69.9714031310119, 'dG_uncer': 3.342651704971682}
# rxn40247 {'dG_mean': -48.98735597930536, 'dG_uncer': 2.031794897751675}
# rxn40248 {'dG_mean': -4.198558651367691, 'dG_uncer': 3.29360193981747}
# rxn40250 {'dG_mean': -134.69940079033506, 'dG_uncer': 3.470632064683109}
# rxn40251 {'dG_mean': -129.76983819011969, 'dG_uncer': 2.7336352214039006}
# rxn40252 {'dG_mean': 15.232434930742343, 'dG_uncer': 3.248676142769764}
# rxn40253 {'dG_mean': -28.138572209136555, 'dG_uncer': 1.05553909506723}
# rxn40254 {'dG_mean': -7.506854750750406, 'dG_uncer': 1.1239988859365295}
# rxn40255 {'dG_mean': -123.51179771058771, 'dG_uncer': 1.596222726362309}
# rxn40256 {'dG_mean': 32.025527821771504, 'dG_uncer': 1.1276761743874706}
# rxn40257 {'dG_mean': 110.43089973317058, 'dG_uncer': 1.5582194357479118}
# rxn40258 {'dG_mean': 47.80466955566234, 'dG_uncer': 1.6469444911353657}
# rxn40259 {'dG_mean': 2.058028609914963, 'dG_uncer': 1.3196838429972717}
# rxn40260 {'dG_mean': 43.52625187076308, 'dG_uncer': 3.111718785066748}
# rxn40262 {'dG_mean': -168.1645395031628, 'dG_uncer': 1.4568290718691046}
# rxn40263 {'dG_mean': -76.42904785664318, 'dG_uncer': 2.479723727176945}
# rxn40264 {'dG_mean': -342.9267553515035, 'dG_uncer': 0.1813008994435448}
# rxn40265 {'dG_mean': -84.89674027349896, 'dG_uncer': 3.274837372299772}
# rxn40266 {'dG_mean': -37.6717235813104, 'dG_uncer': 1.329277303029441}
# rxn40267 {'dG_mean': -533.4400697640033, 'dG_uncer': 2.835535668687335}
# rxn40268 {'dG_mean': -404.59425378841, 'dG_uncer': 0.7508628450569284}
# rxn40269 {'dG_mean': -404.59425375508806, 'dG_uncer': 0.7508628450569284}
# rxn40270 {'dG_mean': -378.282067022617, 'dG_uncer': 3.2688837022294845}
# rxn40273 {'dG_mean': -270.65162982126355, 'dG_uncer': 2.918353088339725}
# rxn40274 {'dG_mean': -445.2568582562313, 'dG_uncer': 1.5965483796108553}
# rxn40275 {'dG_mean': 3.534364040152127, 'dG_uncer': 0.8246648736660732}
# rxn40276 {'dG_mean': -17.851237128038576, 'dG_uncer': 3.2390423109499413}
# rxn40277 {'dG_mean': -15.154931902839644, 'dG_uncer': 3.348729554346501}
# rxn40278 {'dG_mean': -23.467948497736785, 'dG_uncer': 3.5994255245077937}
# rxn40279 {'dG_mean': 12.974524300225028, 'dG_uncer': 0.6138324151448269}
# rxn40280 {'dG_mean': -112.09322288485625, 'dG_uncer': 4.061470046101138}
# rxn40284 {'dG_mean': -53.07841021413071, 'dG_uncer': 1.0567851723204331}
# rxn40285 {'dG_mean': 17.72883975442358, 'dG_uncer': 0.9311832224765544}
# rxn40286 {'dG_mean': -6.438798572582755, 'dG_uncer': 0.786509288177567}
# rxn40289 {'dG_mean': -15.243756828670303, 'dG_uncer': 4.125127542109102}
# rxn40293 {'dG_mean': -26.66011183343012, 'dG_uncer': 1.3756555800635066}
# rxn40296 {'dG_mean': -459.3417341498673, 'dG_uncer': 0.150991089211429}
# rxn40297 {'dG_mean': 28.841339815374823, 'dG_uncer': 1.1470466060558504}
# rxn40299 {'dG_mean': 24.52180387902668, 'dG_uncer': 3.2854518220165367}
# rxn40300 {'dG_mean': 17.56138424695191, 'dG_uncer': 3.334775656787869}
# rxn40302 {'dG_mean': 3.986192791357361, 'dG_uncer': 3.4542434134218536}
# rxn40303 {'dG_mean': -444.118599098587, 'dG_uncer': 1.5965483796108553}
# rxn40305 {'dG_mean': 3.4049630472283923, 'dG_uncer': 3.583618847806471}
# rxn40307 {'dG_mean': -3.103747497170417, 'dG_uncer': 1.1392583165599963}
# rxn40309 {'dG_mean': 33.587945819190224, 'dG_uncer': 2.3198963689652787}
# rxn40310 {'dG_mean': -440.8476888310631, 'dG_uncer': 1.5984232213115093}
# rxn40311 {'dG_mean': -392.234734853266, 'dG_uncer': 1.401690422073538}
# rxn40312 {'dG_mean': 23.86376210831108, 'dG_uncer': 0.9228261345543703}
# rxn40313 {'dG_mean': -441.9859479887073, 'dG_uncer': 1.5984232213115093}
# rxn40314 {'dG_mean': -66.31846891192725, 'dG_uncer': 1.1319539220212675}
# rxn40315 {'dG_mean': -54.52788150197847, 'dG_uncer': 1.3979800803596572}
# rxn40316 {'dG_mean': 84.08947346940187, 'dG_uncer': 2.1772728804939927}
# rxn40317 {'dG_mean': 71.42668012594582, 'dG_uncer': 3.2779353001625338}
# rxn40318 {'dG_mean': -14.737510615834026, 'dG_uncer': 0.1022898756454585}
# rxn40323 {'dG_mean': 0.5855686368920061, 'dG_uncer': 0.6983032911669589}
# rxn40324 {'dG_mean': -81.67030380892496, 'dG_uncer': 2.7977506523595337}
# rxn40325 {'dG_mean': 18.454501958767025, 'dG_uncer': 0.8677098391012616}
# rxn40331 {'dG_mean': -6.574308351524032, 'dG_uncer': 1.2585520829704795}
# rxn40334 {'dG_mean': -85.04195373441817, 'dG_uncer': 3.0709691512361545}
# rxn40335 {'dG_mean': -91.92794084957418, 'dG_uncer': 2.5355264005024}
# rxn40336 {'dG_mean': -91.92794084957418, 'dG_uncer': 2.5355264005024}
# rxn40337 {'dG_mean': 31.039875056132782, 'dG_uncer': 1.077940844258385}
# rxn40339 {'dG_mean': 35.650249989646056, 'dG_uncer': 2.662654144587465}
# rxn40340 {'dG_mean': 25.667316057759702, 'dG_uncer': 2.308998879574503}
# rxn40341 {'dG_mean': -27.10369723377792, 'dG_uncer': 1.4751524916671674}
# rxn40344 {'dG_mean': -93.39173051513956, 'dG_uncer': 3.4262232404906343}
# rxn40345 {'dG_mean': -50.319217002576025, 'dG_uncer': 2.8584099708257726}
# rxn40346 {'dG_mean': -394.1359124672581, 'dG_uncer': 1.368435046298654}
# rxn40347 {'dG_mean': 53.72594096290891, 'dG_uncer': 1.3939120660050444}
# rxn40351 {'dG_mean': -42.56628546182272, 'dG_uncer': 2.6544831076333857}
# rxn40352 {'dG_mean': -4.111760668353554, 'dG_uncer': 0.5740234310424568}
# rxn40354 {'dG_mean': -474.6090085970756, 'dG_uncer': 0.2537942939117089}
# rxn40356 {'dG_mean': -31.473184191507386, 'dG_uncer': 0.664602112801701}
# rxn40358 {'dG_mean': -50.22254939005008, 'dG_uncer': 1.842295026186324}
# rxn40359 {'dG_mean': -45.38237877045238, 'dG_uncer': 2.2364577015498424}
# rxn40362 {'dG_mean': -23.913372780124234, 'dG_uncer': 0.1357393941775272}
# rxn40364 {'dG_mean': -11.210997166477096, 'dG_uncer': 0.1604365824856306}
# rxn40365 {'dG_mean': -37.64666595840973, 'dG_uncer': 0.1026628096105937}
# rxn40366 {'dG_mean': 10.672365526866272, 'dG_uncer': 0.1430013925312888}
# rxn40368 {'dG_mean': 20.21439897489817, 'dG_uncer': 1.0287987454376482}
# rxn40371 {'dG_mean': -38.519472265466845, 'dG_uncer': 2.7730591410263847}
# rxn40372 {'dG_mean': -38.51818134926242, 'dG_uncer': 2.7730591410263847}
# rxn40374 {'dG_mean': -407.3219787013908, 'dG_uncer': 1.171227203877112}
# rxn40375 {'dG_mean': -818.9662089438701, 'dG_uncer': 2.3902370998825946}
# rxn40376 {'dG_mean': -818.9778557271765, 'dG_uncer': 2.3902370998825946}
# rxn40377 {'dG_mean': -175.40884967783404, 'dG_uncer': 2.479511403462598}
# rxn40378 {'dG_mean': 157.3095491954017, 'dG_uncer': 2.6878528005223026}
# rxn40379 {'dG_mean': -177.85529891561123, 'dG_uncer': 2.479511403462598}
# rxn40380 {'dG_mean': 167.07827931381524, 'dG_uncer': 2.479681375438004}
# rxn40383 {'dG_mean': -107.81508604124878, 'dG_uncer': 2.177228056715855}
# rxn40384 {'dG_mean': -105.36894529534896, 'dG_uncer': 2.177228056715855}
# rxn40385 {'dG_mean': -558.7042214105368, 'dG_uncer': 2.92774372368366}
# rxn40386 {'dG_mean': -45.14307753578549, 'dG_uncer': 0.656782590639825}
# rxn40387 {'dG_mean': -28.618937293349333, 'dG_uncer': 2.1316459254734683}
# rxn40388 {'dG_mean': -18.524688454023966, 'dG_uncer': 1.3029087372945185}
# rxn40389 {'dG_mean': -23.191493318452984, 'dG_uncer': 1.2638243078114098}
# rxn40390 {'dG_mean': 6.533478648813912, 'dG_uncer': 1.3577724672943348}
# rxn40402 {'dG_mean': -409.4945157793928, 'dG_uncer': 2.1652245795623384}
# rxn40405 {'dG_mean': -355.6496089247853, 'dG_uncer': 2.538647376123864}
# rxn40406 {'dG_mean': -271.8035724027702, 'dG_uncer': 2.114061773735026}
# rxn40407 {'dG_mean': -477.2335715034926, 'dG_uncer': 2.0682021704457103}
# rxn40408 {'dG_mean': -749.0371439062626, 'dG_uncer': 2.122056268519797}
# rxn40409 {'dG_mean': 7.347312485985654, 'dG_uncer': 1.711940733163747}
# rxn40410 {'dG_mean': -40.6549131009329, 'dG_uncer': 2.849583862963739}
# rxn40411 {'dG_mean': -140.4110420460275, 'dG_uncer': 3.760999477454392}
# rxn40413 {'dG_mean': -470.35886612256894, 'dG_uncer': 3.1445123342994323}
# rxn40414 {'dG_mean': -757.4937938777028, 'dG_uncer': 2.4230579576283167}
# rxn40415 {'dG_mean': -470.3726129241086, 'dG_uncer': 3.1445123342994323}
# rxn40416 {'dG_mean': 38.73588780904479, 'dG_uncer': 0.7714997477049303}
# rxn40417 {'dG_mean': 33.85692952750648, 'dG_uncer': 1.3008167880866572}
# rxn40418 {'dG_mean': -6.014095195513754, 'dG_uncer': 0.8326122838552175}
# rxn40419 {'dG_mean': -23.49377248015969, 'dG_uncer': 1.6651889494555054}
# rxn40420 {'dG_mean': -78.86110940857324, 'dG_uncer': 2.575243845028301}
# rxn40421 {'dG_mean': -79.40893634594761, 'dG_uncer': 2.646164840345289}
# rxn40422 {'dG_mean': -21.295139040829284, 'dG_uncer': 4.386810266161369}
# rxn40423 {'dG_mean': -24.88024295524272, 'dG_uncer': 1.9774301314191909}
# rxn40429 {'dG_mean': 52.10149323853089, 'dG_uncer': 2.5752417013361626}
# rxn40430 {'dG_mean': -26.211789232667897, 'dG_uncer': 3.594314213514579}
# rxn40431 {'dG_mean': -11.248688059860427, 'dG_uncer': 1.2577526601092297}
# rxn40433 {'dG_mean': -1140.789017827061, 'dG_uncer': 5.933366634696455}
# rxn40434 {'dG_mean': -0.5478269373744808, 'dG_uncer': 3.5943239497943136}
# rxn40435 {'dG_mean': -1131.8865991331431, 'dG_uncer': 6.225793223544581}
# rxn40436 {'dG_mean': -23.64771705688408, 'dG_uncer': 0.1045762377507601}
# rxn40437 {'dG_mean': 80.02723967174589, 'dG_uncer': 2.576358707662408}
# rxn40438 {'dG_mean': 1.7729143880212916, 'dG_uncer': 1.2004318049806235}
# rxn40439 {'dG_mean': 14.01044427149455, 'dG_uncer': 1.2428660670885805}
# rxn40440 {'dG_mean': -6.995276366077846, 'dG_uncer': 1.1804995907203786}
# rxn40441 {'dG_mean': -417.8011163765251, 'dG_uncer': 0.1911416362281582}
# rxn40442 {'dG_mean': 9.537404891268352, 'dG_uncer': 0.1020911397960782}
# rxn40443 {'dG_mean': -473.4039533158557, 'dG_uncer': 1.589988322976364}
# rxn40444 {'dG_mean': 49.79804378703204, 'dG_uncer': 1.5873914672645628}
# rxn40446 {'dG_mean': -105.00628455843466, 'dG_uncer': 3.4037565389389632}
# rxn40447 {'dG_mean': -21.693429463611032, 'dG_uncer': 3.4391103576436137}
# rxn40448 {'dG_mean': -33.77059041392863, 'dG_uncer': 0.1160141716170173}
# rxn40452 {'dG_mean': 26.707171640544686, 'dG_uncer': 0.8769095648097809}
# rxn40453 {'dG_mean': 25.51175782661824, 'dG_uncer': 0.4872679895821158}
# rxn40454 {'dG_mean': -835.8991908137305, 'dG_uncer': 3.8854089536129073}
# rxn40455 {'dG_mean': -209.4246454680607, 'dG_uncer': 1.6182193540295604}
# rxn40456 {'dG_mean': -694.22234343936, 'dG_uncer': 2.236014559681617}
# rxn40457 {'dG_mean': -476.3684833987864, 'dG_uncer': 0.8989627590549926}
# rxn40458 {'dG_mean': -360.77630567558816, 'dG_uncer': 1.599083758819935}
# rxn40459 {'dG_mean': -380.3012523667531, 'dG_uncer': 1.7000680894709377}
# rxn40460 {'dG_mean': -133.25635418813818, 'dG_uncer': 5.039569614343556}
# rxn40461 {'dG_mean': -749.3449507842504, 'dG_uncer': 4.976936484544621}
# rxn40462 {'dG_mean': -458.2587080702479, 'dG_uncer': 3.0342629526963893}
# rxn40463 {'dG_mean': -376.0865498588752, 'dG_uncer': 3.838325947074924}
# rxn40464 {'dG_mean': -27.551735406451144, 'dG_uncer': 1.9594481291316288}
# rxn40466 {'dG_mean': -459.5610824380825, 'dG_uncer': 0.5558434049324295}
# rxn40467 {'dG_mean': -30.23356566363063, 'dG_uncer': 2.657982983994556}
# rxn40471 {'dG_mean': -534.1720609949199, 'dG_uncer': 3.4278578389183707}
# rxn40472 {'dG_mean': -546.2297001418472, 'dG_uncer': 2.6176071989522907}
# rxn40473 {'dG_mean': -380.1268494683724, 'dG_uncer': 1.8733878968780624}
# rxn40474 {'dG_mean': -76.2532498898832, 'dG_uncer': 3.4748473976618417}
# rxn40476 {'dG_mean': -7.066076413979516, 'dG_uncer': 1.628423352166119}
# rxn40477 {'dG_mean': -8.170364509018867, 'dG_uncer': 1.628423352166119}
# rxn40478 {'dG_mean': -6.035538682677611, 'dG_uncer': 0.4525842383416485}
# rxn40480 {'dG_mean': -0.0401443494049065, 'dG_uncer': 1.1801964869466566}
# rxn40481 {'dG_mean': 39.91859116279227, 'dG_uncer': 2.236730234932359}
# rxn40482 {'dG_mean': 6.800731633297332, 'dG_uncer': 1.84988373096041}
# rxn40483 {'dG_mean': -37.7611150135312, 'dG_uncer': 2.054861032855062}
# rxn40485 {'dG_mean': 51.18488967171066, 'dG_uncer': 2.623888647776537}

# %%
print(MSDB_json["rxn00014"]["deltag"])
from numpy import array_split

# export JSON processing
MSDB_lists = array_split(list(MSDB_json.values()), 61)
# Out:
# 41840000.0

# %%
for index, portion in enumerate(MSDB_lists):
    with open(f"reaction_{index:02}.json", "w") as jsonOut:
        dump(list(portion), jsonOut, indent=3)

# %%
msdb = from_local(r"C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDDatabase")

# %%
print(msdb.reactions.rxn00001.delta_g)
# Out:
# -3.46
